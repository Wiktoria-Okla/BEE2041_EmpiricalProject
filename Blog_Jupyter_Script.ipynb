# %%
pip install requests beautifulsoup4 pandas numpy
# Out:
# Requirement already satisfied: requests in c:\users\wikto\anaconda3\lib\site-packages (2.25.1)Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: beautifulsoup4 in c:\users\wikto\anaconda3\lib\site-packages (4.9.3)
# Requirement already satisfied: pandas in c:\users\wikto\anaconda3\lib\site-packages (1.2.4)
# Requirement already satisfied: numpy in c:\users\wikto\anaconda3\lib\site-packages (1.20.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\wikto\anaconda3\lib\site-packages (from beautifulsoup4) (2.2.1)
# Requirement already satisfied: pytz>=2017.3 in c:\users\wikto\anaconda3\lib\site-packages (from pandas) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\wikto\anaconda3\lib\site-packages (from pandas) (2.8.1)
# Requirement already satisfied: six>=1.5 in c:\users\wikto\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\wikto\anaconda3\lib\site-packages (from requests) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\wikto\anaconda3\lib\site-packages (from requests) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\wikto\anaconda3\lib\site-packages (from requests) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\wikto\anaconda3\lib\site-packages (from requests) (1.26.4)

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

# %% [markdown]
# ### Creating a scraping function

# %%
#creating a function which looks for tables and 
def scraping_function(table_url):
    results_response = requests.get(table_url)
    results_soup = BeautifulSoup(results_response.text, 'html.parser')
    
    race_tables = [] #creating an empty dataframe
    
    for table in results_soup.find_all('table'):
        table_name = table.find_previous('h2').text.strip()
        race_scraped = pd.read_html(str(table))[0]
        race_tables.append(race_scraped)
    final_df = pd.concat(race_tables, ignore_index = True)
        
    return final_df

# %% [markdown]
# ### Scraping the necessary datasets

# %% [markdown]
# Scraping races data

# %%
races = scraping_function('https://www.formula1.com/en/results.html/2023/races.html')
races
# Out:
#     Unnamed: 0     Grand Prix         Date              Winner  \
# 0          NaN        Bahrain  05 Mar 2023  Max Verstappen VER
# 1          NaN   Saudi Arabia  19 Mar 2023    Sergio Perez PER
# 2          NaN      Australia  02 Apr 2023  Max Verstappen VER
# 3          NaN     Azerbaijan  30 Apr 2023    Sergio Perez PER
# 4          NaN          Miami  07 May 2023  Max Verstappen VER
# 5          NaN         Monaco  28 May 2023  Max Verstappen VER
# 6          NaN          Spain  04 Jun 2023  Max Verstappen VER
# 7          NaN         Canada  18 Jun 2023  Max Verstappen VER
# 8          NaN        Austria  02 Jul 2023  Max Verstappen VER
# 9          NaN  Great Britain  09 Jul 2023  Max Verstappen VER
# 10         NaN        Hungary  23 Jul 2023  Max Verstappen VER
# 11         NaN        Belgium  30 Jul 2023  Max Verstappen VER
# 12         NaN    Netherlands  27 Aug 2023  Max Verstappen VER
# 13         NaN          Italy  03 Sep 2023  Max Verstappen VER
# 14         NaN      Singapore  17 Sep 2023    Carlos Sainz SAI
# 15         NaN          Japan  24 Sep 2023  Max Verstappen VER
# 16         NaN          Qatar  08 Oct 2023  Max Verstappen VER
# 17         NaN  United States  22 Oct 2023  Max Verstappen VER
# 18         NaN         Mexico  29 Oct 2023  Max Verstappen VER
# 19         NaN         Brazil  05 Nov 2023  Max Verstappen VER
# 20         NaN      Las Vegas  18 Nov 2023  Max Verstappen VER
# 21         NaN      Abu Dhabi  26 Nov 2023  Max Verstappen VER
#
#                            Car  Laps         Time  Unnamed: 7
# 0   Red Bull Racing Honda RBPT    57  1:33:56.736         NaN
# 1   Red Bull Racing Honda RBPT    50  1:21:14.894         NaN
# 2   Red Bull Racing Honda RBPT    58  2:32:38.371         NaN
# 3   Red Bull Racing Honda RBPT    51  1:32:42.436         NaN
# 4   Red Bull Racing Honda RBPT    57  1:27:38.241         NaN
# 5   Red Bull Racing Honda RBPT    78  1:48:51.980         NaN
# 6   Red Bull Racing Honda RBPT    66  1:27:57.940         NaN
# 7   Red Bull Racing Honda RBPT    70  1:33:58.348         NaN
# 8   Red Bull Racing Honda RBPT    71  1:25:33.607         NaN
# 9   Red Bull Racing Honda RBPT    52  1:25:16.938         NaN
# 10  Red Bull Racing Honda RBPT    70  1:38:08.634         NaN
# 11  Red Bull Racing Honda RBPT    44  1:22:30.450         NaN
# 12  Red Bull Racing Honda RBPT    72  2:24:04.411         NaN
# 13  Red Bull Racing Honda RBPT    51  1:13:41.143         NaN
# 14                     Ferrari    62  1:46:37.418         NaN
# 15  Red Bull Racing Honda RBPT    53  1:30:58.421         NaN
# 16  Red Bull Racing Honda RBPT    57  1:27:39.168         NaN
# 17  Red Bull Racing Honda RBPT    56  1:35:21.362         NaN
# 18  Red Bull Racing Honda RBPT    71  2:02:30.814         NaN
# 19  Red Bull Racing Honda RBPT    71  1:56:48.894         NaN
# 20  Red Bull Racing Honda RBPT    50  1:29:08.289         NaN
# 21  Red Bull Racing Honda RBPT    58  1:27:02.624         NaN

# %% [markdown]
# Scraping drivers data

# %%
drivers = scraping_function('https://www.formula1.com/en/results.html/2023/drivers.html')
drivers
# Out:
#     Unnamed: 0  Pos                Driver Nationality  \
# 0          NaN    1    Max Verstappen VER         NED
# 1          NaN    2      Sergio Perez PER         MEX
# 2          NaN    3    Lewis Hamilton HAM         GBR
# 3          NaN    4   Fernando Alonso ALO         ESP
# 4          NaN    5   Charles Leclerc LEC         MON
# 5          NaN    6      Lando Norris NOR         GBR
# 6          NaN    7      Carlos Sainz SAI         ESP
# 7          NaN    8    George Russell RUS         GBR
# 8          NaN    9     Oscar Piastri PIA         AUS
# 9          NaN   10      Lance Stroll STR         CAN
# 10         NaN   11      Pierre Gasly GAS         FRA
# 11         NaN   12      Esteban Ocon OCO         FRA
# 12         NaN   13   Alexander Albon ALB         THA
# 13         NaN   14      Yuki Tsunoda TSU         JPN
# 14         NaN   15   Valtteri Bottas BOT         FIN
# 15         NaN   16   Nico Hulkenberg HUL         GER
# 16         NaN   17  Daniel Ricciardo RIC         AUS
# 17         NaN   18       Zhou Guanyu ZHO         CHN
# 18         NaN   19   Kevin Magnussen MAG         DEN
# 19         NaN   20       Liam Lawson LAW         NZL
# 20         NaN   21    Logan Sargeant SAR         USA
# 21         NaN   22     Nyck De Vries DEV         NED
#
#                              Car  PTS  Unnamed: 6
# 0     Red Bull Racing Honda RBPT  575         NaN
# 1     Red Bull Racing Honda RBPT  285         NaN
# 2                       Mercedes  234         NaN
# 3   Aston Martin Aramco Mercedes  206         NaN
# 4                        Ferrari  206         NaN
# 5               McLaren Mercedes  205         NaN
# 6                        Ferrari  200         NaN
# 7                       Mercedes  175         NaN
# 8               McLaren Mercedes   97         NaN
# 9   Aston Martin Aramco Mercedes   74         NaN
# 10                Alpine Renault   62         NaN
# 11                Alpine Renault   58         NaN
# 12             Williams Mercedes   27         NaN
# 13         AlphaTauri Honda RBPT   17         NaN
# 14            Alfa Romeo Ferrari   10         NaN
# 15                  Haas Ferrari    9         NaN
# 16         AlphaTauri Honda RBPT    6         NaN
# 17            Alfa Romeo Ferrari    6         NaN
# 18                  Haas Ferrari    3         NaN
# 19         AlphaTauri Honda RBPT    2         NaN
# 20             Williams Mercedes    1         NaN
# 21         AlphaTauri Honda RBPT    0         NaN

# %% [markdown]
# Scraping races

# %%
Bahrain = scraping_function('https://www.formula1.com/en/results.html/2023/races/1141/bahrain/race-result.html')
Bahrain
# Out:
#     Unnamed: 0 Pos  No               Driver                           Car  \
# 0          NaN   1   1   Max Verstappen VER    Red Bull Racing Honda RBPT
# 1          NaN   2  11     Sergio Perez PER    Red Bull Racing Honda RBPT
# 2          NaN   3  14  Fernando Alonso ALO  Aston Martin Aramco Mercedes
# 3          NaN   4  55     Carlos Sainz SAI                       Ferrari
# 4          NaN   5  44   Lewis Hamilton HAM                      Mercedes
# 5          NaN   6  18     Lance Stroll STR  Aston Martin Aramco Mercedes
# 6          NaN   7  63   George Russell RUS                      Mercedes
# 7          NaN   8  77  Valtteri Bottas BOT            Alfa Romeo Ferrari
# 8          NaN   9  10     Pierre Gasly GAS                Alpine Renault
# 9          NaN  10  23  Alexander Albon ALB             Williams Mercedes
# 10         NaN  11  22     Yuki Tsunoda TSU         AlphaTauri Honda RBPT
# 11         NaN  12   2   Logan Sargeant SAR             Williams Mercedes
# 12         NaN  13  20  Kevin Magnussen MAG                  Haas Ferrari
# 13         NaN  14  21    Nyck De Vries DEV         AlphaTauri Honda RBPT
# 14         NaN  15  27  Nico Hulkenberg HUL                  Haas Ferrari
# 15         NaN  16  24      Zhou Guanyu ZHO            Alfa Romeo Ferrari
# 16         NaN  17   4     Lando Norris NOR              McLaren Mercedes
# 17         NaN  NC  31     Esteban Ocon OCO                Alpine Renault
# 18         NaN  NC  16  Charles Leclerc LEC                       Ferrari
# 19         NaN  NC  81    Oscar Piastri PIA              McLaren Mercedes
#
#     Laps Time/Retired  PTS  Unnamed: 8
# 0     57  1:33:56.736   25         NaN
# 1     57     +11.987s   18         NaN
# 2     57     +38.637s   15         NaN
# 3     57     +48.052s   12         NaN
# 4     57     +50.977s   10         NaN
# 5     57     +54.502s    8         NaN
# 6     57     +55.873s    6         NaN
# 7     57     +72.647s    4         NaN
# 8     57     +73.753s    2         NaN
# 9     57     +89.774s    1         NaN
# 10    57     +90.870s    0         NaN
# 11    56       +1 lap    0         NaN
# 12    56       +1 lap    0         NaN
# 13    56       +1 lap    0         NaN
# 14    56       +1 lap    0         NaN
# 15    56       +1 lap    0         NaN
# 16    55      +2 laps    0         NaN
# 17    41          DNF    0         NaN
# 18    39          DNF    0         NaN
# 19    13          DNF    0         NaN

# %%
Saudi_arabia = scraping_function('https://www.formula1.com/en/results.html/2023/races/1142/saudi-arabia/race-result.html')
Saudi_arabia
# Out:
#     Unnamed: 0 Pos  No               Driver                           Car  \
# 0          NaN   1  11     Sergio Perez PER    Red Bull Racing Honda RBPT
# 1          NaN   2   1   Max Verstappen VER    Red Bull Racing Honda RBPT
# 2          NaN   3  14  Fernando Alonso ALO  Aston Martin Aramco Mercedes
# 3          NaN   4  63   George Russell RUS                      Mercedes
# 4          NaN   5  44   Lewis Hamilton HAM                      Mercedes
# 5          NaN   6  55     Carlos Sainz SAI                       Ferrari
# 6          NaN   7  16  Charles Leclerc LEC                       Ferrari
# 7          NaN   8  31     Esteban Ocon OCO                Alpine Renault
# 8          NaN   9  10     Pierre Gasly GAS                Alpine Renault
# 9          NaN  10  20  Kevin Magnussen MAG                  Haas Ferrari
# 10         NaN  11  22     Yuki Tsunoda TSU         AlphaTauri Honda RBPT
# 11         NaN  12  27  Nico Hulkenberg HUL                  Haas Ferrari
# 12         NaN  13  24      Zhou Guanyu ZHO            Alfa Romeo Ferrari
# 13         NaN  14  21    Nyck De Vries DEV         AlphaTauri Honda RBPT
# 14         NaN  15  81    Oscar Piastri PIA              McLaren Mercedes
# 15         NaN  16   2   Logan Sargeant SAR             Williams Mercedes
# 16         NaN  17   4     Lando Norris NOR              McLaren Mercedes
# 17         NaN  18  77  Valtteri Bottas BOT            Alfa Romeo Ferrari
# 18         NaN  NC  23  Alexander Albon ALB             Williams Mercedes
# 19         NaN  NC  18     Lance Stroll STR  Aston Martin Aramco Mercedes
#
#     Laps Time/Retired  PTS  Unnamed: 8
# 0     50  1:21:14.894   25         NaN
# 1     50      +5.355s   19         NaN
# 2     50     +20.728s   15         NaN
# 3     50     +25.866s   12         NaN
# 4     50     +31.065s   10         NaN
# 5     50     +35.876s    8         NaN
# 6     50     +43.162s    6         NaN
# 7     50     +52.832s    4         NaN
# 8     50     +54.747s    2         NaN
# 9     50     +64.826s    1         NaN
# 10    50     +67.494s    0         NaN
# 11    50     +70.588s    0         NaN
# 12    50     +76.060s    0         NaN
# 13    50     +77.478s    0         NaN
# 14    50     +85.021s    0         NaN
# 15    50     +86.293s    0         NaN
# 16    50     +86.445s    0         NaN
# 17    49       +1 lap    0         NaN
# 18    27          DNF    0         NaN
# 19    16          DNF    0         NaN

# %%
Australia = scraping_function('https://www.formula1.com/en/results.html/2023/races/1143/australia/race-result.html')
Australia
# Out:
#     Unnamed: 0 Pos  No               Driver                           Car  \
# 0          NaN   1   1   Max Verstappen VER    Red Bull Racing Honda RBPT
# 1          NaN   2  44   Lewis Hamilton HAM                      Mercedes
# 2          NaN   3  14  Fernando Alonso ALO  Aston Martin Aramco Mercedes
# 3          NaN   4  18     Lance Stroll STR  Aston Martin Aramco Mercedes
# 4          NaN   5  11     Sergio Perez PER    Red Bull Racing Honda RBPT
# 5          NaN   6   4     Lando Norris NOR              McLaren Mercedes
# 6          NaN   7  27  Nico Hulkenberg HUL                  Haas Ferrari
# 7          NaN   8  81    Oscar Piastri PIA              McLaren Mercedes
# 8          NaN   9  24      Zhou Guanyu ZHO            Alfa Romeo Ferrari
# 9          NaN  10  22     Yuki Tsunoda TSU         AlphaTauri Honda RBPT
# 10         NaN  11  77  Valtteri Bottas BOT            Alfa Romeo Ferrari
# 11         NaN  12  55     Carlos Sainz SAI                       Ferrari
# 12         NaN  13  10     Pierre Gasly GAS                Alpine Renault
# 13         NaN  14  31     Esteban Ocon OCO                Alpine Renault
# 14         NaN  15  21    Nyck De Vries DEV         AlphaTauri Honda RBPT
# 15         NaN  16   2   Logan Sargeant SAR             Williams Mercedes
# 16         NaN  17  20  Kevin Magnussen MAG                  Haas Ferrari
# 17         NaN  NC  63   George Russell RUS                      Mercedes
# 18         NaN  NC  23  Alexander Albon ALB             Williams Mercedes
# 19         NaN  NC  16  Charles Leclerc LEC                       Ferrari
#
#     Laps Time/Retired  PTS  Unnamed: 8
# 0     58  2:32:38.371   25         NaN
# 1     58      +0.179s   18         NaN
# 2     58      +0.769s   15         NaN
# 3     58      +3.082s   12         NaN
# 4     58      +3.320s   11         NaN
# 5     58      +3.701s    8         NaN
# 6     58      +4.939s    6         NaN
# 7     58      +5.382s    4         NaN
# 8     58      +5.713s    2         NaN
# 9     58      +6.052s    1         NaN
# 10    58      +6.513s    0         NaN
# 11    58      +6.594s    0         NaN
# 12    56          DNF    0         NaN
# 13    56          DNF    0         NaN
# 14    56          DNF    0         NaN
# 15    56          DNF    0         NaN
# 16    52          DNF    0         NaN
# 17    17          DNF    0         NaN
# 18     6          DNF    0         NaN
# 19     0          DNF    0         NaN

# %%
Azerbaijan = scraping_function('https://www.formula1.com/en/results.html/2023/races/1207/azerbaijan/race-result.html')
Azerbaijan
# Out:
#     Unnamed: 0 Pos  No               Driver                           Car  \
# 0          NaN   1  11     Sergio Perez PER    Red Bull Racing Honda RBPT
# 1          NaN   2   1   Max Verstappen VER    Red Bull Racing Honda RBPT
# 2          NaN   3  16  Charles Leclerc LEC                       Ferrari
# 3          NaN   4  14  Fernando Alonso ALO  Aston Martin Aramco Mercedes
# 4          NaN   5  55     Carlos Sainz SAI                       Ferrari
# 5          NaN   6  44   Lewis Hamilton HAM                      Mercedes
# 6          NaN   7  18     Lance Stroll STR  Aston Martin Aramco Mercedes
# 7          NaN   8  63   George Russell RUS                      Mercedes
# 8          NaN   9   4     Lando Norris NOR              McLaren Mercedes
# 9          NaN  10  22     Yuki Tsunoda TSU         AlphaTauri Honda RBPT
# 10         NaN  11  81    Oscar Piastri PIA              McLaren Mercedes
# 11         NaN  12  23  Alexander Albon ALB             Williams Mercedes
# 12         NaN  13  20  Kevin Magnussen MAG                  Haas Ferrari
# 13         NaN  14  10     Pierre Gasly GAS                Alpine Renault
# 14         NaN  15  31     Esteban Ocon OCO                Alpine Renault
# 15         NaN  16   2   Logan Sargeant SAR             Williams Mercedes
# 16         NaN  17  27  Nico Hulkenberg HUL                  Haas Ferrari
# 17         NaN  18  77  Valtteri Bottas BOT            Alfa Romeo Ferrari
# 18         NaN  NC  24      Zhou Guanyu ZHO            Alfa Romeo Ferrari
# 19         NaN  NC  21    Nyck De Vries DEV         AlphaTauri Honda RBPT
#
#     Laps Time/Retired  PTS  Unnamed: 8
# 0     51  1:32:42.436   25         NaN
# 1     51      +2.137s   18         NaN
# 2     51     +21.217s   15         NaN
# 3     51     +22.024s   12         NaN
# 4     51     +45.491s   10         NaN
# 5     51     +46.145s    8         NaN
# 6     51     +51.617s    6         NaN
# 7     51     +74.240s    5         NaN
# 8     51     +80.376s    2         NaN
# 9     51     +83.862s    1         NaN
# 10    51     +86.501s    0         NaN
# 11    51     +88.623s    0         NaN
# 12    51     +89.729s    0         NaN
# 13    51     +91.332s    0         NaN
# 14    51     +97.794s    0         NaN
# 15    51    +100.943s    0         NaN
# 16    50       +1 lap    0         NaN
# 17    50       +1 lap    0         NaN
# 18    36          DNF    0         NaN
# 19     9          DNF    0         NaN

# %%
Miami = scraping_function('https://www.formula1.com/en/results.html/2023/races/1208/miami/race-result.html')
Miami
# Out:
#     Unnamed: 0  Pos  No               Driver                           Car  \
# 0          NaN    1   1   Max Verstappen VER    Red Bull Racing Honda RBPT
# 1          NaN    2  11     Sergio Perez PER    Red Bull Racing Honda RBPT
# 2          NaN    3  14  Fernando Alonso ALO  Aston Martin Aramco Mercedes
# 3          NaN    4  63   George Russell RUS                      Mercedes
# 4          NaN    5  55     Carlos Sainz SAI                       Ferrari
# 5          NaN    6  44   Lewis Hamilton HAM                      Mercedes
# 6          NaN    7  16  Charles Leclerc LEC                       Ferrari
# 7          NaN    8  10     Pierre Gasly GAS                Alpine Renault
# 8          NaN    9  31     Esteban Ocon OCO                Alpine Renault
# 9          NaN   10  20  Kevin Magnussen MAG                  Haas Ferrari
# 10         NaN   11  22     Yuki Tsunoda TSU         AlphaTauri Honda RBPT
# 11         NaN   12  18     Lance Stroll STR  Aston Martin Aramco Mercedes
# 12         NaN   13  77  Valtteri Bottas BOT            Alfa Romeo Ferrari
# 13         NaN   14  23  Alexander Albon ALB             Williams Mercedes
# 14         NaN   15  27  Nico Hulkenberg HUL                  Haas Ferrari
# 15         NaN   16  24      Zhou Guanyu ZHO            Alfa Romeo Ferrari
# 16         NaN   17   4     Lando Norris NOR              McLaren Mercedes
# 17         NaN   18  21    Nyck De Vries DEV         AlphaTauri Honda RBPT
# 18         NaN   19  81    Oscar Piastri PIA              McLaren Mercedes
# 19         NaN   20   2   Logan Sargeant SAR             Williams Mercedes
#
#     Laps Time/Retired  PTS  Unnamed: 8
# 0     57  1:27:38.241   26         NaN
# 1     57      +5.384s   18         NaN
# 2     57     +26.305s   15         NaN
# 3     57     +33.229s   12         NaN
# 4     57     +42.511s   10         NaN
# 5     57     +51.249s    8         NaN
# 6     57     +52.988s    6         NaN
# 7     57     +55.670s    4         NaN
# 8     57     +58.123s    2         NaN
# 9     57     +62.945s    1         NaN
# 10    57     +64.309s    0         NaN
# 11    57     +64.754s    0         NaN
# 12    57     +71.637s    0         NaN
# 13    57     +72.861s    0         NaN
# 14    57     +74.950s    0         NaN
# 15    57     +78.440s    0         NaN
# 16    57     +87.717s    0         NaN
# 17    57     +88.949s    0         NaN
# 18    56       +1 lap    0         NaN
# 19    56       +1 lap    0         NaN

# %%
Emilia_romagna = scraping_function('https://www.formula1.com/en/results.html/2023/races/1209/italy.html')
Emilia_romagna 
#note this race was cancelled hence we get no results and an error when we try to scrape the race data
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-157-d830662a71d7> in <module>
# ----> 1 Emilia_romagna = scraping_function('https://www.formula1.com/en/results.html/2023/races/1209/italy.html')
#       2 Emilia_romagna
#       3 #note this race was cancelled hence we get no results and an error when we try to scrape the race data
#
# <ipython-input-149-3d5808911cc7> in scraping_function(table_url)
#      10         race_scraped = pd.read_html(str(table))[0]
#      11         race_tables.append(race_scraped)
# ---> 12     final_df = pd.concat(race_tables, ignore_index = True)
#      13
#      14     return final_df
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     283     ValueError: Indexes have overlapping values: ['a']
#     284     """
# --> 285     op = _Concatenator(
#     286         objs,
#     287         axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     340
#     341         if len(objs) == 0:
# --> 342             raise ValueError("No objects to concatenate")
#     343
#     344         if keys is None:
#
# ValueError: No objects to concatenate

# %%
Monaco = scraping_function('https://www.formula1.com/en/results.html/2023/races/1210/monaco/race-result.html')
Monaco

# %%
Spain = scraping_function('https://www.formula1.com/en/results.html/2023/races/1211/spain/race-result.html')
Spain

# %%
Canada = scraping_function('https://www.formula1.com/en/results.html/2023/races/1212/canada/race-result.html')
Canada
# Out:
#     Unnamed: 0 Pos  No               Driver                           Car  \
# 0          NaN   1   1   Max Verstappen VER    Red Bull Racing Honda RBPT
# 1          NaN   2  14  Fernando Alonso ALO  Aston Martin Aramco Mercedes
# 2          NaN   3  44   Lewis Hamilton HAM                      Mercedes
# 3          NaN   4  16  Charles Leclerc LEC                       Ferrari
# 4          NaN   5  55     Carlos Sainz SAI                       Ferrari
# 5          NaN   6  11     Sergio Perez PER    Red Bull Racing Honda RBPT
# 6          NaN   7  23  Alexander Albon ALB             Williams Mercedes
# 7          NaN   8  31     Esteban Ocon OCO                Alpine Renault
# 8          NaN   9  18     Lance Stroll STR  Aston Martin Aramco Mercedes
# 9          NaN  10  77  Valtteri Bottas BOT            Alfa Romeo Ferrari
# 10         NaN  11  81    Oscar Piastri PIA              McLaren Mercedes
# 11         NaN  12  10     Pierre Gasly GAS                Alpine Renault
# 12         NaN  13   4     Lando Norris NOR              McLaren Mercedes
# 13         NaN  14  22     Yuki Tsunoda TSU         AlphaTauri Honda RBPT
# 14         NaN  15  27  Nico Hulkenberg HUL                  Haas Ferrari
# 15         NaN  16  24      Zhou Guanyu ZHO            Alfa Romeo Ferrari
# 16         NaN  17  20  Kevin Magnussen MAG                  Haas Ferrari
# 17         NaN  18  21    Nyck De Vries DEV         AlphaTauri Honda RBPT
# 18         NaN  NC  63   George Russell RUS                      Mercedes
# 19         NaN  NC   2   Logan Sargeant SAR             Williams Mercedes
#
#     Laps Time/Retired  PTS  Unnamed: 8
# 0     70  1:33:58.348   25         NaN
# 1     70      +9.570s   18         NaN
# 2     70     +14.168s   15         NaN
# 3     70     +18.648s   12         NaN
# 4     70     +21.540s   10         NaN
# 5     70     +51.028s    9         NaN
# 6     70     +60.813s    6         NaN
# 7     70     +61.692s    4         NaN
# 8     70     +64.402s    2         NaN
# 9     70     +64.432s    1         NaN
# 10    70     +65.101s    0         NaN
# 11    70     +65.249s    0         NaN
# 12    70     +68.363s    0         NaN
# 13    70     +73.423s    0         NaN
# 14    69       +1 lap    0         NaN
# 15    69       +1 lap    0         NaN
# 16    69       +1 lap    0         NaN
# 17    69       +1 lap    0         NaN
# 18    53          DNF    0         NaN
# 19     6          DNF    0         NaN

# %%
Austria = scraping_function('https://www.formula1.com/en/results.html/2023/races/1213/austria/race-result.html')
Austria
# Out:
#     Unnamed: 0 Pos  No               Driver                           Car  \
# 0          NaN   1   1   Max Verstappen VER    Red Bull Racing Honda RBPT
# 1          NaN   2  16  Charles Leclerc LEC                       Ferrari
# 2          NaN   3  11     Sergio Perez PER    Red Bull Racing Honda RBPT
# 3          NaN   4   4     Lando Norris NOR              McLaren Mercedes
# 4          NaN   5  14  Fernando Alonso ALO  Aston Martin Aramco Mercedes
# 5          NaN   6  55     Carlos Sainz SAI                       Ferrari
# 6          NaN   7  63   George Russell RUS                      Mercedes
# 7          NaN   8  44   Lewis Hamilton HAM                      Mercedes
# 8          NaN   9  18     Lance Stroll STR  Aston Martin Aramco Mercedes
# 9          NaN  10  10     Pierre Gasly GAS                Alpine Renault
# 10         NaN  11  23  Alexander Albon ALB             Williams Mercedes
# 11         NaN  12  24      Zhou Guanyu ZHO            Alfa Romeo Ferrari
# 12         NaN  13   2   Logan Sargeant SAR             Williams Mercedes
# 13         NaN  14  31     Esteban Ocon OCO                Alpine Renault
# 14         NaN  15  77  Valtteri Bottas BOT            Alfa Romeo Ferrari
# 15         NaN  16  81    Oscar Piastri PIA              McLaren Mercedes
# 16         NaN  17  21    Nyck De Vries DEV         AlphaTauri Honda RBPT
# 17         NaN  18  20  Kevin Magnussen MAG                  Haas Ferrari
# 18         NaN  19  22     Yuki Tsunoda TSU         AlphaTauri Honda RBPT
# 19         NaN  NC  27  Nico Hulkenberg HUL                  Haas Ferrari
#
#     Laps Time/Retired  PTS  Unnamed: 8
# 0     71  1:25:33.607   26         NaN
# 1     71      +5.155s   18         NaN
# 2     71     +17.188s   15         NaN
# 3     71     +26.327s   12         NaN
# 4     71     +30.317s   10         NaN
# 5     71     +31.377s    8         NaN
# 6     71     +48.403s    6         NaN
# 7     71     +49.196s    4         NaN
# 8     71     +59.043s    2         NaN
# 9     71     +67.667s    1         NaN
# 10    71     +79.767s    0         NaN
# 11    70       +1 lap    0         NaN
# 12    70       +1 lap    0         NaN
# 13    70       +1 lap    0         NaN
# 14    70       +1 lap    0         NaN
# 15    70       +1 lap    0         NaN
# 16    70       +1 lap    0         NaN
# 17    70       +1 lap    0         NaN
# 18    70       +1 lap    0         NaN
# 19    12          DNF    0         NaN

# %%
Great_britain = scraping_function('https://www.formula1.com/en/results.html/2023/races/1214/great-britain/race-result.html')
Great_britain
# Out:
#     Unnamed: 0 Pos  No               Driver                           Car  \
# 0          NaN   1   1   Max Verstappen VER    Red Bull Racing Honda RBPT
# 1          NaN   2   4     Lando Norris NOR              McLaren Mercedes
# 2          NaN   3  44   Lewis Hamilton HAM                      Mercedes
# 3          NaN   4  81    Oscar Piastri PIA              McLaren Mercedes
# 4          NaN   5  63   George Russell RUS                      Mercedes
# 5          NaN   6  11     Sergio Perez PER    Red Bull Racing Honda RBPT
# 6          NaN   7  14  Fernando Alonso ALO  Aston Martin Aramco Mercedes
# 7          NaN   8  23  Alexander Albon ALB             Williams Mercedes
# 8          NaN   9  16  Charles Leclerc LEC                       Ferrari
# 9          NaN  10  55     Carlos Sainz SAI                       Ferrari
# 10         NaN  11   2   Logan Sargeant SAR             Williams Mercedes
# 11         NaN  12  77  Valtteri Bottas BOT            Alfa Romeo Ferrari
# 12         NaN  13  27  Nico Hulkenberg HUL                  Haas Ferrari
# 13         NaN  14  18     Lance Stroll STR  Aston Martin Aramco Mercedes
# 14         NaN  15  24      Zhou Guanyu ZHO            Alfa Romeo Ferrari
# 15         NaN  16  22     Yuki Tsunoda TSU         AlphaTauri Honda RBPT
# 16         NaN  17  21    Nyck De Vries DEV         AlphaTauri Honda RBPT
# 17         NaN  18  10     Pierre Gasly GAS                Alpine Renault
# 18         NaN  NC  20  Kevin Magnussen MAG                  Haas Ferrari
# 19         NaN  NC  31     Esteban Ocon OCO                Alpine Renault
#
#     Laps Time/Retired  PTS  Unnamed: 8
# 0     52  1:25:16.938   26         NaN
# 1     52      +3.798s   18         NaN
# 2     52      +6.783s   15         NaN
# 3     52      +7.776s   12         NaN
# 4     52     +11.206s   10         NaN
# 5     52     +12.882s    8         NaN
# 6     52     +17.193s    6         NaN
# 7     52     +17.878s    4         NaN
# 8     52     +18.689s    2         NaN
# 9     52     +19.448s    1         NaN
# 10    52     +23.632s    0         NaN
# 11    52     +25.830s    0         NaN
# 12    52     +26.663s    0         NaN
# 13    52     +27.483s    0         NaN
# 14    52     +29.820s    0         NaN
# 15    52     +31.225s    0         NaN
# 16    52     +33.128s    0         NaN
# 17    46          DNF    0         NaN
# 18    31          DNF    0         NaN
# 19     9          DNF    0         NaN

# %%
Hungary = scraping_function('https://www.formula1.com/en/results.html/2023/races/1215/hungary/race-result.html')
Hungary
# Out:
#     Unnamed: 0 Pos  No                Driver                           Car  \
# 0          NaN   1   1    Max Verstappen VER    Red Bull Racing Honda RBPT
# 1          NaN   2   4      Lando Norris NOR              McLaren Mercedes
# 2          NaN   3  11      Sergio Perez PER    Red Bull Racing Honda RBPT
# 3          NaN   4  44    Lewis Hamilton HAM                      Mercedes
# 4          NaN   5  81     Oscar Piastri PIA              McLaren Mercedes
# 5          NaN   6  63    George Russell RUS                      Mercedes
# 6          NaN   7  16   Charles Leclerc LEC                       Ferrari
# 7          NaN   8  55      Carlos Sainz SAI                       Ferrari
# 8          NaN   9  14   Fernando Alonso ALO  Aston Martin Aramco Mercedes
# 9          NaN  10  18      Lance Stroll STR  Aston Martin Aramco Mercedes
# 10         NaN  11  23   Alexander Albon ALB             Williams Mercedes
# 11         NaN  12  77   Valtteri Bottas BOT            Alfa Romeo Ferrari
# 12         NaN  13   3  Daniel Ricciardo RIC         AlphaTauri Honda RBPT
# 13         NaN  14  27   Nico Hulkenberg HUL                  Haas Ferrari
# 14         NaN  15  22      Yuki Tsunoda TSU         AlphaTauri Honda RBPT
# 15         NaN  16  24       Zhou Guanyu ZHO            Alfa Romeo Ferrari
# 16         NaN  17  20   Kevin Magnussen MAG                  Haas Ferrari
# 17         NaN  18   2    Logan Sargeant SAR             Williams Mercedes
# 18         NaN  NC  31      Esteban Ocon OCO                Alpine Renault
# 19         NaN  NC  10      Pierre Gasly GAS                Alpine Renault
#
#     Laps Time/Retired  PTS  Unnamed: 8
# 0     70  1:38:08.634   26         NaN
# 1     70     +33.731s   18         NaN
# 2     70     +37.603s   15         NaN
# 3     70     +39.134s   12         NaN
# 4     70     +62.572s   10         NaN
# 5     70     +65.825s    8         NaN
# 6     70     +70.317s    6         NaN
# 7     70     +71.073s    4         NaN
# 8     70     +75.709s    2         NaN
# 9     69       +1 lap    1         NaN
# 10    69       +1 lap    0         NaN
# 11    69       +1 lap    0         NaN
# 12    69       +1 lap    0         NaN
# 13    69       +1 lap    0         NaN
# 14    69       +1 lap    0         NaN
# 15    69       +1 lap    0         NaN
# 16    69       +1 lap    0         NaN
# 17    67          DNF    0         NaN
# 18     2          DNF    0         NaN
# 19     1          DNF    0         NaN

# %%
Belgium = scraping_function('https://www.formula1.com/en/results.html/2023/races/1216/belgium/race-result.html')
Belgium
# Out:
#     Unnamed: 0 Pos  No                Driver                           Car  \
# 0          NaN   1   1    Max Verstappen VER    Red Bull Racing Honda RBPT
# 1          NaN   2  11      Sergio Perez PER    Red Bull Racing Honda RBPT
# 2          NaN   3  16   Charles Leclerc LEC                       Ferrari
# 3          NaN   4  44    Lewis Hamilton HAM                      Mercedes
# 4          NaN   5  14   Fernando Alonso ALO  Aston Martin Aramco Mercedes
# 5          NaN   6  63    George Russell RUS                      Mercedes
# 6          NaN   7   4      Lando Norris NOR              McLaren Mercedes
# 7          NaN   8  31      Esteban Ocon OCO                Alpine Renault
# 8          NaN   9  18      Lance Stroll STR  Aston Martin Aramco Mercedes
# 9          NaN  10  22      Yuki Tsunoda TSU         AlphaTauri Honda RBPT
# 10         NaN  11  10      Pierre Gasly GAS                Alpine Renault
# 11         NaN  12  77   Valtteri Bottas BOT            Alfa Romeo Ferrari
# 12         NaN  13  24       Zhou Guanyu ZHO            Alfa Romeo Ferrari
# 13         NaN  14  23   Alexander Albon ALB             Williams Mercedes
# 14         NaN  15  20   Kevin Magnussen MAG                  Haas Ferrari
# 15         NaN  16   3  Daniel Ricciardo RIC         AlphaTauri Honda RBPT
# 16         NaN  17   2    Logan Sargeant SAR             Williams Mercedes
# 17         NaN  18  27   Nico Hulkenberg HUL                  Haas Ferrari
# 18         NaN  NC  55      Carlos Sainz SAI                       Ferrari
# 19         NaN  NC  81     Oscar Piastri PIA              McLaren Mercedes
#
#     Laps Time/Retired  PTS  Unnamed: 8
# 0     44  1:22:30.450   25         NaN
# 1     44     +22.305s   18         NaN
# 2     44     +32.259s   15         NaN
# 3     44     +49.671s   13         NaN
# 4     44     +56.184s   10         NaN
# 5     44     +63.101s    8         NaN
# 6     44     +73.719s    6         NaN
# 7     44     +74.719s    4         NaN
# 8     44     +79.340s    2         NaN
# 9     44     +80.221s    1         NaN
# 10    44     +83.084s    0         NaN
# 11    44     +85.191s    0         NaN
# 12    44     +95.441s    0         NaN
# 13    44     +96.184s    0         NaN
# 14    44    +101.754s    0         NaN
# 15    44    +103.071s    0         NaN
# 16    44    +104.476s    0         NaN
# 17    44    +110.450s    0         NaN
# 18    23          DNF    0         NaN
# 19     0          DNF    0         NaN

# %%
Netherlands = scraping_function('https://www.formula1.com/en/results.html/2023/races/1217/netherlands/race-result.html')
Netherlands
# Out:
#     Unnamed: 0 Pos  No               Driver                           Car  \
# 0          NaN   1   1   Max Verstappen VER    Red Bull Racing Honda RBPT
# 1          NaN   2  14  Fernando Alonso ALO  Aston Martin Aramco Mercedes
# 2          NaN   3  10     Pierre Gasly GAS                Alpine Renault
# 3          NaN   4  11     Sergio Perez PER    Red Bull Racing Honda RBPT
# 4          NaN   5  55     Carlos Sainz SAI                       Ferrari
# 5          NaN   6  44   Lewis Hamilton HAM                      Mercedes
# 6          NaN   7   4     Lando Norris NOR              McLaren Mercedes
# 7          NaN   8  23  Alexander Albon ALB             Williams Mercedes
# 8          NaN   9  81    Oscar Piastri PIA              McLaren Mercedes
# 9          NaN  10  31     Esteban Ocon OCO                Alpine Renault
# 10         NaN  11  18     Lance Stroll STR  Aston Martin Aramco Mercedes
# 11         NaN  12  27  Nico Hulkenberg HUL                  Haas Ferrari
# 12         NaN  13  40      Liam Lawson LAW         AlphaTauri Honda RBPT
# 13         NaN  14  77  Valtteri Bottas BOT            Alfa Romeo Ferrari
# 14         NaN  15  22     Yuki Tsunoda TSU         AlphaTauri Honda RBPT
# 15         NaN  16  20  Kevin Magnussen MAG                  Haas Ferrari
# 16         NaN  17  63   George Russell RUS                      Mercedes
# 17         NaN  NC  24      Zhou Guanyu ZHO            Alfa Romeo Ferrari
# 18         NaN  NC  16  Charles Leclerc LEC                       Ferrari
# 19         NaN  NC   2   Logan Sargeant SAR             Williams Mercedes
#
#     Laps Time/Retired  PTS  Unnamed: 8
# 0     72  2:24:04.411   25         NaN
# 1     72      +3.744s   19         NaN
# 2     72      +7.058s   15         NaN
# 3     72     +10.068s   12         NaN
# 4     72     +12.541s   10         NaN
# 5     72     +13.209s    8         NaN
# 6     72     +13.232s    6         NaN
# 7     72     +15.155s    4         NaN
# 8     72     +16.580s    2         NaN
# 9     72     +18.346s    1         NaN
# 10    72     +20.087s    0         NaN
# 11    72     +20.840s    0         NaN
# 12    72     +26.147s    0         NaN
# 13    72     +27.388s    0         NaN
# 14    72     +29.893s    0         NaN
# 15    72     +31.410s    0         NaN
# 16    72     +55.754s    0         NaN
# 17    62          DNF    0         NaN
# 18    41          DNF    0         NaN
# 19    14          DNF    0         NaN

# %%
Italy = scraping_function('https://www.formula1.com/en/results.html/2023/races/1218/italy/race-result.html')
Italy
# Out:
#     Unnamed: 0 Pos  No               Driver                           Car  \
# 0          NaN   1   1   Max Verstappen VER    Red Bull Racing Honda RBPT
# 1          NaN   2  11     Sergio Perez PER    Red Bull Racing Honda RBPT
# 2          NaN   3  55     Carlos Sainz SAI                       Ferrari
# 3          NaN   4  16  Charles Leclerc LEC                       Ferrari
# 4          NaN   5  63   George Russell RUS                      Mercedes
# 5          NaN   6  44   Lewis Hamilton HAM                      Mercedes
# 6          NaN   7  23  Alexander Albon ALB             Williams Mercedes
# 7          NaN   8   4     Lando Norris NOR              McLaren Mercedes
# 8          NaN   9  14  Fernando Alonso ALO  Aston Martin Aramco Mercedes
# 9          NaN  10  77  Valtteri Bottas BOT            Alfa Romeo Ferrari
# 10         NaN  11  40      Liam Lawson LAW         AlphaTauri Honda RBPT
# 11         NaN  12  81    Oscar Piastri PIA              McLaren Mercedes
# 12         NaN  13   2   Logan Sargeant SAR             Williams Mercedes
# 13         NaN  14  24      Zhou Guanyu ZHO            Alfa Romeo Ferrari
# 14         NaN  15  10     Pierre Gasly GAS                Alpine Renault
# 15         NaN  16  18     Lance Stroll STR  Aston Martin Aramco Mercedes
# 16         NaN  17  27  Nico Hulkenberg HUL                  Haas Ferrari
# 17         NaN  18  20  Kevin Magnussen MAG                  Haas Ferrari
# 18         NaN  NC  31     Esteban Ocon OCO                Alpine Renault
# 19         NaN  NC  22     Yuki Tsunoda TSU         AlphaTauri Honda RBPT
#
#     Laps Time/Retired  PTS  Unnamed: 8
# 0     51  1:13:41.143   25         NaN
# 1     51      +6.064s   18         NaN
# 2     51     +11.193s   15         NaN
# 3     51     +11.377s   12         NaN
# 4     51     +23.028s   10         NaN
# 5     51     +42.679s    8         NaN
# 6     51     +45.106s    6         NaN
# 7     51     +45.449s    4         NaN
# 8     51     +46.294s    2         NaN
# 9     51     +64.056s    1         NaN
# 10    51     +70.638s    0         NaN
# 11    51     +73.074s    0         NaN
# 12    51     +78.557s    0         NaN
# 13    51     +80.164s    0         NaN
# 14    51     +82.510s    0         NaN
# 15    51     +87.266s    0         NaN
# 16    50       +1 lap    0         NaN
# 17    50       +1 lap    0         NaN
# 18    39          DNF    0         NaN
# 19     0          DNS    0         NaN

# %%
Singapore = scraping_function('https://www.formula1.com/en/results.html/2023/races/1219/singapore/race-result.html')
Singapore
# Out:
#     Unnamed: 0 Pos  No               Driver                           Car  \
# 0          NaN   1  55     Carlos Sainz SAI                       Ferrari
# 1          NaN   2   4     Lando Norris NOR              McLaren Mercedes
# 2          NaN   3  44   Lewis Hamilton HAM                      Mercedes
# 3          NaN   4  16  Charles Leclerc LEC                       Ferrari
# 4          NaN   5   1   Max Verstappen VER    Red Bull Racing Honda RBPT
# 5          NaN   6  10     Pierre Gasly GAS                Alpine Renault
# 6          NaN   7  81    Oscar Piastri PIA              McLaren Mercedes
# 7          NaN   8  11     Sergio Perez PER    Red Bull Racing Honda RBPT
# 8          NaN   9  40      Liam Lawson LAW         AlphaTauri Honda RBPT
# 9          NaN  10  20  Kevin Magnussen MAG                  Haas Ferrari
# 10         NaN  11  23  Alexander Albon ALB             Williams Mercedes
# 11         NaN  12  24      Zhou Guanyu ZHO            Alfa Romeo Ferrari
# 12         NaN  13  27  Nico Hulkenberg HUL                  Haas Ferrari
# 13         NaN  14   2   Logan Sargeant SAR             Williams Mercedes
# 14         NaN  15  14  Fernando Alonso ALO  Aston Martin Aramco Mercedes
# 15         NaN  16  63   George Russell RUS                      Mercedes
# 16         NaN  NC  77  Valtteri Bottas BOT            Alfa Romeo Ferrari
# 17         NaN  NC  31     Esteban Ocon OCO                Alpine Renault
# 18         NaN  NC  22     Yuki Tsunoda TSU         AlphaTauri Honda RBPT
#
#     Laps Time/Retired  PTS  Unnamed: 8
# 0     62  1:46:37.418   25         NaN
# 1     62      +0.812s   18         NaN
# 2     62      +1.269s   16         NaN
# 3     62     +21.177s   12         NaN
# 4     62     +21.441s   10         NaN
# 5     62     +38.441s    8         NaN
# 6     62     +41.479s    6         NaN
# 7     62     +59.534s    4         NaN
# 8     62     +65.918s    2         NaN
# 9     62     +72.116s    1         NaN
# 10    62     +73.417s    0         NaN
# 11    62     +83.649s    0         NaN
# 12    62     +86.201s    0         NaN
# 13    62     +86.889s    0         NaN
# 14    62     +87.603s    0         NaN
# 15    61          DNF    0         NaN
# 16    51          DNF    0         NaN
# 17    42          DNF    0         NaN
# 18     0          DNF    0         NaN

# %%
Japan = scraping_function('https://www.formula1.com/en/results.html/2023/races/1220/japan/race-result.html')
Japan
# Out:
#     Unnamed: 0 Pos  No               Driver                           Car  \
# 0          NaN   1   1   Max Verstappen VER    Red Bull Racing Honda RBPT
# 1          NaN   2   4     Lando Norris NOR              McLaren Mercedes
# 2          NaN   3  81    Oscar Piastri PIA              McLaren Mercedes
# 3          NaN   4  16  Charles Leclerc LEC                       Ferrari
# 4          NaN   5  44   Lewis Hamilton HAM                      Mercedes
# 5          NaN   6  55     Carlos Sainz SAI                       Ferrari
# 6          NaN   7  63   George Russell RUS                      Mercedes
# 7          NaN   8  14  Fernando Alonso ALO  Aston Martin Aramco Mercedes
# 8          NaN   9  31     Esteban Ocon OCO                Alpine Renault
# 9          NaN  10  10     Pierre Gasly GAS                Alpine Renault
# 10         NaN  11  40      Liam Lawson LAW         AlphaTauri Honda RBPT
# 11         NaN  12  22     Yuki Tsunoda TSU         AlphaTauri Honda RBPT
# 12         NaN  13  24      Zhou Guanyu ZHO            Alfa Romeo Ferrari
# 13         NaN  14  27  Nico Hulkenberg HUL                  Haas Ferrari
# 14         NaN  15  20  Kevin Magnussen MAG                  Haas Ferrari
# 15         NaN  NC  23  Alexander Albon ALB             Williams Mercedes
# 16         NaN  NC   2   Logan Sargeant SAR             Williams Mercedes
# 17         NaN  NC  18     Lance Stroll STR  Aston Martin Aramco Mercedes
# 18         NaN  NC  11     Sergio Perez PER    Red Bull Racing Honda RBPT
# 19         NaN  NC  77  Valtteri Bottas BOT            Alfa Romeo Ferrari
#
#     Laps Time/Retired  PTS  Unnamed: 8
# 0     53  1:30:58.421   26         NaN
# 1     53     +19.387s   18         NaN
# 2     53     +36.494s   15         NaN
# 3     53     +43.998s   12         NaN
# 4     53     +49.376s   10         NaN
# 5     53     +50.221s    8         NaN
# 6     53     +57.659s    6         NaN
# 7     53     +74.725s    4         NaN
# 8     53     +79.678s    2         NaN
# 9     53     +83.155s    1         NaN
# 10    52       +1 lap    0         NaN
# 11    52       +1 lap    0         NaN
# 12    52       +1 lap    0         NaN
# 13    52       +1 lap    0         NaN
# 14    52       +1 lap    0         NaN
# 15    26          DNF    0         NaN
# 16    22          DNF    0         NaN
# 17    20          DNF    0         NaN
# 18    15          DNF    0         NaN
# 19     7          DNF    0         NaN

# %%
Qatar = scraping_function('https://www.formula1.com/en/results.html/2023/races/1221/qatar/race-result.html')
Qatar
# Out:
#     Unnamed: 0 Pos  No               Driver                           Car  \
# 0          NaN   1   1   Max Verstappen VER    Red Bull Racing Honda RBPT
# 1          NaN   2  81    Oscar Piastri PIA              McLaren Mercedes
# 2          NaN   3   4     Lando Norris NOR              McLaren Mercedes
# 3          NaN   4  63   George Russell RUS                      Mercedes
# 4          NaN   5  16  Charles Leclerc LEC                       Ferrari
# 5          NaN   6  14  Fernando Alonso ALO  Aston Martin Aramco Mercedes
# 6          NaN   7  31     Esteban Ocon OCO                Alpine Renault
# 7          NaN   8  77  Valtteri Bottas BOT            Alfa Romeo Ferrari
# 8          NaN   9  24      Zhou Guanyu ZHO            Alfa Romeo Ferrari
# 9          NaN  10  11     Sergio Perez PER    Red Bull Racing Honda RBPT
# 10         NaN  11  18     Lance Stroll STR  Aston Martin Aramco Mercedes
# 11         NaN  12  10     Pierre Gasly GAS                Alpine Renault
# 12         NaN  13  23  Alexander Albon ALB             Williams Mercedes
# 13         NaN  14  20  Kevin Magnussen MAG                  Haas Ferrari
# 14         NaN  15  22     Yuki Tsunoda TSU         AlphaTauri Honda RBPT
# 15         NaN  16  27  Nico Hulkenberg HUL                  Haas Ferrari
# 16         NaN  17  40      Liam Lawson LAW         AlphaTauri Honda RBPT
# 17         NaN  NC   2   Logan Sargeant SAR             Williams Mercedes
# 18         NaN  NC  44   Lewis Hamilton HAM                      Mercedes
# 19         NaN  NC  55     Carlos Sainz SAI                       Ferrari
#
#     Laps Time/Retired  PTS  Unnamed: 8
# 0     57  1:27:39.168   26         NaN
# 1     57      +4.833s   18         NaN
# 2     57      +5.969s   15         NaN
# 3     57     +34.119s   12         NaN
# 4     57     +38.976s   10         NaN
# 5     57     +49.032s    8         NaN
# 6     57     +62.390s    6         NaN
# 7     57     +66.563s    4         NaN
# 8     57     +76.127s    2         NaN
# 9     57     +80.181s    1         NaN
# 10    57     +81.652s    0         NaN
# 11    57     +82.300s    0         NaN
# 12    57     +91.014s    0         NaN
# 13    56       +1 lap    0         NaN
# 14    56       +1 lap    0         NaN
# 15    56       +1 lap    0         NaN
# 16    56       +1 lap    0         NaN
# 17    40          DNF    0         NaN
# 18     0          DNF    0         NaN
# 19     0          DNS    0         NaN

# %%
US = scraping_function('https://www.formula1.com/en/results.html/2023/races/1222/united-states/race-result.html')
US
# Out:
#     Unnamed: 0 Pos  No                Driver                           Car  \
# 0          NaN   1   1    Max Verstappen VER    Red Bull Racing Honda RBPT
# 1          NaN  DQ  44    Lewis Hamilton HAM                      Mercedes
# 2          NaN   2   4      Lando Norris NOR              McLaren Mercedes
# 3          NaN   3  55      Carlos Sainz SAI                       Ferrari
# 4          NaN   4  11      Sergio Perez PER    Red Bull Racing Honda RBPT
# 5          NaN  DQ  16   Charles Leclerc LEC                       Ferrari
# 6          NaN   5  63    George Russell RUS                      Mercedes
# 7          NaN   6  10      Pierre Gasly GAS                Alpine Renault
# 8          NaN   7  18      Lance Stroll STR  Aston Martin Aramco Mercedes
# 9          NaN   8  22      Yuki Tsunoda TSU         AlphaTauri Honda RBPT
# 10         NaN   9  23   Alexander Albon ALB             Williams Mercedes
# 11         NaN  10   2    Logan Sargeant SAR             Williams Mercedes
# 12         NaN  11  27   Nico Hulkenberg HUL                  Haas Ferrari
# 13         NaN  12  77   Valtteri Bottas BOT            Alfa Romeo Ferrari
# 14         NaN  13  24       Zhou Guanyu ZHO            Alfa Romeo Ferrari
# 15         NaN  14  20   Kevin Magnussen MAG                  Haas Ferrari
# 16         NaN  15   3  Daniel Ricciardo RIC         AlphaTauri Honda RBPT
# 17         NaN  NC  14   Fernando Alonso ALO  Aston Martin Aramco Mercedes
# 18         NaN  NC  81     Oscar Piastri PIA              McLaren Mercedes
# 19         NaN  NC  31      Esteban Ocon OCO                Alpine Renault
#
#     Laps Time/Retired  PTS  Unnamed: 8
# 0     56  1:35:21.362   25         NaN
# 1     56      +2.225s    0         NaN
# 2     56     +10.730s   18         NaN
# 3     56     +15.134s   15         NaN
# 4     56     +18.460s   12         NaN
# 5     56     +24.662s    0         NaN
# 6     56     +24.999s   10         NaN
# 7     56     +47.996s    8         NaN
# 8     56     +48.696s    6         NaN
# 9     56     +74.385s    5         NaN
# 10    56     +86.714s    2         NaN
# 11    56     +87.998s    1         NaN
# 12    56     +89.904s    0         NaN
# 13    56     +98.601s    0         NaN
# 14    55       +1 lap    0         NaN
# 15    55       +1 lap    0         NaN
# 16    55       +1 lap    0         NaN
# 17    49          DNF    0         NaN
# 18    10          DNF    0         NaN
# 19     6          DNF    0         NaN

# %%
Mexico = scraping_function('https://www.formula1.com/en/results.html/2023/races/1223/mexico/race-result.html')
Mexico
# Out:
#     Unnamed: 0 Pos  No                Driver                           Car  \
# 0          NaN   1   1    Max Verstappen VER    Red Bull Racing Honda RBPT
# 1          NaN   2  44    Lewis Hamilton HAM                      Mercedes
# 2          NaN   3  16   Charles Leclerc LEC                       Ferrari
# 3          NaN   4  55      Carlos Sainz SAI                       Ferrari
# 4          NaN   5   4      Lando Norris NOR              McLaren Mercedes
# 5          NaN   6  63    George Russell RUS                      Mercedes
# 6          NaN   7   3  Daniel Ricciardo RIC         AlphaTauri Honda RBPT
# 7          NaN   8  81     Oscar Piastri PIA              McLaren Mercedes
# 8          NaN   9  23   Alexander Albon ALB             Williams Mercedes
# 9          NaN  10  31      Esteban Ocon OCO                Alpine Renault
# 10         NaN  11  10      Pierre Gasly GAS                Alpine Renault
# 11         NaN  12  22      Yuki Tsunoda TSU         AlphaTauri Honda RBPT
# 12         NaN  13  27   Nico Hulkenberg HUL                  Haas Ferrari
# 13         NaN  14  24       Zhou Guanyu ZHO            Alfa Romeo Ferrari
# 14         NaN  15  77   Valtteri Bottas BOT            Alfa Romeo Ferrari
# 15         NaN  16   2    Logan Sargeant SAR             Williams Mercedes
# 16         NaN  17  18      Lance Stroll STR  Aston Martin Aramco Mercedes
# 17         NaN  NC  14   Fernando Alonso ALO  Aston Martin Aramco Mercedes
# 18         NaN  NC  20   Kevin Magnussen MAG                  Haas Ferrari
# 19         NaN  NC  11      Sergio Perez PER    Red Bull Racing Honda RBPT
#
#     Laps Time/Retired  PTS  Unnamed: 8
# 0     71  2:02:30.814   25         NaN
# 1     71     +13.875s   19         NaN
# 2     71     +23.124s   15         NaN
# 3     71     +27.154s   12         NaN
# 4     71     +33.266s   10         NaN
# 5     71     +41.020s    8         NaN
# 6     71     +41.570s    6         NaN
# 7     71     +43.104s    4         NaN
# 8     71     +48.573s    2         NaN
# 9     71     +62.879s    1         NaN
# 10    71     +66.208s    0         NaN
# 11    71     +78.982s    0         NaN
# 12    71     +80.309s    0         NaN
# 13    71     +81.676s    0         NaN
# 14    71     +85.597s    0         NaN
# 15    70          DNF    0         NaN
# 16    66          DNF    0         NaN
# 17    47          DNF    0         NaN
# 18    31          DNF    0         NaN
# 19     1          DNF    0         NaN

# %%
Brazil = scraping_function('https://www.formula1.com/en/results.html/2023/races/1224/brazil/race-result.html')
Brazil
# Out:
#     Unnamed: 0 Pos  No                Driver                           Car  \
# 0          NaN   1   1    Max Verstappen VER    Red Bull Racing Honda RBPT
# 1          NaN   2   4      Lando Norris NOR              McLaren Mercedes
# 2          NaN   3  14   Fernando Alonso ALO  Aston Martin Aramco Mercedes
# 3          NaN   4  11      Sergio Perez PER    Red Bull Racing Honda RBPT
# 4          NaN   5  18      Lance Stroll STR  Aston Martin Aramco Mercedes
# 5          NaN   6  55      Carlos Sainz SAI                       Ferrari
# 6          NaN   7  10      Pierre Gasly GAS                Alpine Renault
# 7          NaN   8  44    Lewis Hamilton HAM                      Mercedes
# 8          NaN   9  22      Yuki Tsunoda TSU         AlphaTauri Honda RBPT
# 9          NaN  10  31      Esteban Ocon OCO                Alpine Renault
# 10         NaN  11   2    Logan Sargeant SAR             Williams Mercedes
# 11         NaN  12  27   Nico Hulkenberg HUL                  Haas Ferrari
# 12         NaN  13   3  Daniel Ricciardo RIC         AlphaTauri Honda RBPT
# 13         NaN  14  81     Oscar Piastri PIA              McLaren Mercedes
# 14         NaN  NC  63    George Russell RUS                      Mercedes
# 15         NaN  NC  77   Valtteri Bottas BOT            Alfa Romeo Ferrari
# 16         NaN  NC  24       Zhou Guanyu ZHO            Alfa Romeo Ferrari
# 17         NaN  NC  20   Kevin Magnussen MAG                  Haas Ferrari
# 18         NaN  NC  23   Alexander Albon ALB             Williams Mercedes
# 19         NaN  NC  16   Charles Leclerc LEC                       Ferrari
#
#     Laps Time/Retired  PTS  Unnamed: 8
# 0     71  1:56:48.894   25         NaN
# 1     71      +8.277s   19         NaN
# 2     71     +34.155s   15         NaN
# 3     71     +34.208s   12         NaN
# 4     71     +40.845s   10         NaN
# 5     71     +50.188s    8         NaN
# 6     71     +56.093s    6         NaN
# 7     71     +62.859s    4         NaN
# 8     71     +69.880s    2         NaN
# 9     70       +1 lap    1         NaN
# 10    70       +1 lap    0         NaN
# 11    70       +1 lap    0         NaN
# 12    70       +1 lap    0         NaN
# 13    69      +2 laps    0         NaN
# 14    57          DNF    0         NaN
# 15    39          DNF    0         NaN
# 16    22          DNF    0         NaN
# 17     0          DNF    0         NaN
# 18     0          DNF    0         NaN
# 19     0          DNS    0         NaN

# %%
Las_vegas = scraping_function('https://www.formula1.com/en/results.html/2023/races/1225/las-vegas/race-result.html')
Las_vegas
# Out:
#     Unnamed: 0 Pos  No                Driver                           Car  \
# 0          NaN   1   1    Max Verstappen VER    Red Bull Racing Honda RBPT
# 1          NaN   2  16   Charles Leclerc LEC                       Ferrari
# 2          NaN   3  11      Sergio Perez PER    Red Bull Racing Honda RBPT
# 3          NaN   4  31      Esteban Ocon OCO                Alpine Renault
# 4          NaN   5  18      Lance Stroll STR  Aston Martin Aramco Mercedes
# 5          NaN   6  55      Carlos Sainz SAI                       Ferrari
# 6          NaN   7  44    Lewis Hamilton HAM                      Mercedes
# 7          NaN   8  63    George Russell RUS                      Mercedes
# 8          NaN   9  14   Fernando Alonso ALO  Aston Martin Aramco Mercedes
# 9          NaN  10  81     Oscar Piastri PIA              McLaren Mercedes
# 10         NaN  11  10      Pierre Gasly GAS                Alpine Renault
# 11         NaN  12  23   Alexander Albon ALB             Williams Mercedes
# 12         NaN  13  20   Kevin Magnussen MAG                  Haas Ferrari
# 13         NaN  14   3  Daniel Ricciardo RIC         AlphaTauri Honda RBPT
# 14         NaN  15  24       Zhou Guanyu ZHO            Alfa Romeo Ferrari
# 15         NaN  16   2    Logan Sargeant SAR             Williams Mercedes
# 16         NaN  17  77   Valtteri Bottas BOT            Alfa Romeo Ferrari
# 17         NaN  18  22      Yuki Tsunoda TSU         AlphaTauri Honda RBPT
# 18         NaN  19  27   Nico Hulkenberg HUL                  Haas Ferrari
# 19         NaN  NC   4      Lando Norris NOR              McLaren Mercedes
#
#     Laps Time/Retired  PTS  Unnamed: 8
# 0     50  1:29:08.289   25         NaN
# 1     50      +2.070s   18         NaN
# 2     50      +2.241s   15         NaN
# 3     50     +18.665s   12         NaN
# 4     50     +20.067s   10         NaN
# 5     50     +20.834s    8         NaN
# 6     50     +21.755s    6         NaN
# 7     50     +23.091s    4         NaN
# 8     50     +25.964s    2         NaN
# 9     50     +29.496s    2         NaN
# 10    50     +34.270s    0         NaN
# 11    50     +43.398s    0         NaN
# 12    50     +44.825s    0         NaN
# 13    50     +48.525s    0         NaN
# 14    50     +50.162s    0         NaN
# 15    50     +50.882s    0         NaN
# 16    50     +85.350s    0         NaN
# 17    46          DNF    0         NaN
# 18    45          DNF    0         NaN
# 19     2          DNF    0         NaN

# %%
Abu_dhabi = scraping_function('https://www.formula1.com/en/results.html/2023/races/1226/abu-dhabi/race-result.html')
Abu_dhabi
# Out:
#     Unnamed: 0  Pos  No                Driver                           Car  \
# 0          NaN    1   1    Max Verstappen VER    Red Bull Racing Honda RBPT
# 1          NaN    2  16   Charles Leclerc LEC                       Ferrari
# 2          NaN    3  63    George Russell RUS                      Mercedes
# 3          NaN    4  11      Sergio Perez PER    Red Bull Racing Honda RBPT
# 4          NaN    5   4      Lando Norris NOR              McLaren Mercedes
# 5          NaN    6  81     Oscar Piastri PIA              McLaren Mercedes
# 6          NaN    7  14   Fernando Alonso ALO  Aston Martin Aramco Mercedes
# 7          NaN    8  22      Yuki Tsunoda TSU         AlphaTauri Honda RBPT
# 8          NaN    9  44    Lewis Hamilton HAM                      Mercedes
# 9          NaN   10  18      Lance Stroll STR  Aston Martin Aramco Mercedes
# 10         NaN   11   3  Daniel Ricciardo RIC         AlphaTauri Honda RBPT
# 11         NaN   12  31      Esteban Ocon OCO                Alpine Renault
# 12         NaN   13  10      Pierre Gasly GAS                Alpine Renault
# 13         NaN   14  23   Alexander Albon ALB             Williams Mercedes
# 14         NaN   15  27   Nico Hulkenberg HUL                  Haas Ferrari
# 15         NaN   16   2    Logan Sargeant SAR             Williams Mercedes
# 16         NaN   17  24       Zhou Guanyu ZHO            Alfa Romeo Ferrari
# 17         NaN   18  55      Carlos Sainz SAI                       Ferrari
# 18         NaN   19  77   Valtteri Bottas BOT            Alfa Romeo Ferrari
# 19         NaN   20  20   Kevin Magnussen MAG                  Haas Ferrari
#
#     Laps Time/Retired  PTS  Unnamed: 8
# 0     58  1:27:02.624   26         NaN
# 1     58     +17.993s   18         NaN
# 2     58     +20.328s   15         NaN
# 3     58     +21.453s   12         NaN
# 4     58     +24.284s   10         NaN
# 5     58     +31.487s    8         NaN
# 6     58     +39.512s    6         NaN
# 7     58     +43.088s    4         NaN
# 8     58     +44.424s    2         NaN
# 9     58     +55.632s    1         NaN
# 10    58     +56.229s    0         NaN
# 11    58     +66.373s    0         NaN
# 12    58     +70.360s    0         NaN
# 13    58     +73.184s    0         NaN
# 14    58     +83.696s    0         NaN
# 15    58     +87.791s    0         NaN
# 16    58     +89.422s    0         NaN
# 17    57          DNF    0         NaN
# 18    57       +1 lap    0         NaN
# 19    57       +1 lap    0         NaN

# %% [markdown]
# Scraping Qualifiers data

# %%
Bahrain_qual = scraping_function('https://www.formula1.com/en/results.html/2023/races/1141/bahrain/qualifying.html')
Saudi_arabia_qual = scraping_function('https://www.formula1.com/en/results.html/2023/races/1142/saudi-arabia/qualifying.html')
Australia_qual = scraping_function('https://www.formula1.com/en/results.html/2023/races/1143/australia/qualifying.html')
Azerbaijan_qual = scraping_function('https://www.formula1.com/en/results.html/2023/races/1207/azerbaijan/qualifying.html')
Miami_qual = scraping_function('https://www.formula1.com/en/results.html/2023/races/1208/miami/qualifying.html')
Monaco_qual = scraping_function('https://www.formula1.com/en/results.html/2023/races/1210/monaco/qualifying.html')
Spain_qual = scraping_function('https://www.formula1.com/en/results.html/2023/races/1211/spain/qualifying.html')
Canada_qual = scraping_function('https://www.formula1.com/en/results.html/2023/races/1212/canada/qualifying.html')
Austria_qual = scraping_function('https://www.formula1.com/en/results.html/2023/races/1213/austria/qualifying.html')
Great_britain_qual = scraping_function('https://www.formula1.com/en/results.html/2023/races/1214/great-britain/qualifying.html')
Hungary_qual = scraping_function('https://www.formula1.com/en/results.html/2023/races/1215/hungary/qualifying.html')
Belgium_qual = scraping_function('https://www.formula1.com/en/results.html/2023/races/1216/belgium/qualifying.html')
Netherlands_qual = scraping_function('https://www.formula1.com/en/results.html/2023/races/1217/netherlands/qualifying.html')
Italy_qual = scraping_function('https://www.formula1.com/en/results.html/2023/races/1218/italy/qualifying.html')
Singapore_qual = scraping_function('https://www.formula1.com/en/results.html/2023/races/1219/singapore/qualifying.html')
Japan_qual = scraping_function('https://www.formula1.com/en/results.html/2023/races/1220/japan/qualifying.html')
Qatar_qual = scraping_function('https://www.formula1.com/en/results.html/2023/races/1221/qatar/qualifying.html')
US_qual = scraping_function('https://www.formula1.com/en/results.html/2023/races/1222/united-states/qualifying.html')
Mexico_qual = scraping_function('https://www.formula1.com/en/results.html/2023/races/1223/mexico/qualifying.html')
Brazil_qual = scraping_function('https://www.formula1.com/en/results.html/2023/races/1224/brazil/qualifying.html')
Las_vegas_qual = scraping_function('https://www.formula1.com/en/results.html/2023/races/1225/las-vegas/qualifying.html')
Abu_dhabi_qual = scraping_function('https://www.formula1.com/en/results.html/2023/races/1226/abu-dhabi/qualifying.html')

# %%
#rename 'Pos' column for qualifying dataset to PosQ to distniguish between qualifying and race positions in the final dataset I am building
qual_data = [Bahrain_qual, Saudi_arabia_qual, Australia_qual, Azerbaijan_qual, Miami_qual, 
             Monaco_qual, Spain_qual, Canada_qual, Austria_qual, Great_britain_qual, Hungary_qual, 
             Belgium_qual, Netherlands_qual, Italy_qual, Singapore_qual, Japan_qual, Qatar_qual, 
             US_qual, Mexico_qual, Brazil_qual, Las_vegas_qual, Abu_dhabi_qual]

for df in qual_data:
    df.rename(columns={'Pos': 'PosQ'}, inplace=True)

# %%
#Merging final results and qualifiers datasets for each race
#results_data = [Bahrain, Saudi_arabia, Australia, Azerbaijan, Miami, Monaco, Spain, Canada, Austria, Great_britain, Hungary, Belgium, Netherlands, Italy, Singapore, Japan, Qatar, US, Mexico, Brazil, Las_vegas, Abu_dhabi]
Bahrain = pd.merge(Bahrain, Bahrain_qual[['Driver', 'PosQ', 'Q1', 'Q2', 'Q3']], on = 'Driver', 
                   how = 'inner')
Saudi_arabia = pd.merge(Saudi_arabia, Saudi_arabia_qual[['Driver', 'PosQ', 'Q1', 'Q2', 'Q3']], on = 'Driver', 
                   how = 'inner')
Australia = pd.merge(Australia, Australia_qual[['Driver', 'PosQ', 'Q1', 'Q2', 'Q3']], on = 'Driver', 
                   how = 'inner')
Azerbaijan = pd.merge(Azerbaijan, Azerbaijan_qual[['Driver', 'PosQ', 'Q1', 'Q2', 'Q3']], on = 'Driver', 
                   how = 'inner')
Miami = pd.merge(Miami, Miami_qual[['Driver', 'PosQ', 'Q1', 'Q2', 'Q3']], on = 'Driver', 
                   how = 'inner')
Monaco = pd.merge(Monaco, Monaco_qual[['Driver', 'PosQ', 'Q1', 'Q2', 'Q3']], on = 'Driver', 
                   how = 'inner')
Spain = pd.merge(Spain, Spain_qual[['Driver', 'PosQ', 'Q1', 'Q2', 'Q3']], on = 'Driver', 
                   how = 'inner')
Canada = pd.merge(Canada, Canada_qual[['Driver', 'PosQ', 'Q1', 'Q2', 'Q3']], on = 'Driver', 
                   how = 'inner')
Austria = pd.merge(Austria, Austria_qual[['Driver', 'PosQ', 'Q1', 'Q2', 'Q3']], on = 'Driver', 
                   how = 'inner')
Great_britain = pd.merge(Great_britain, Great_britain_qual[['Driver', 'PosQ', 'Q1', 'Q2', 'Q3']], on = 'Driver', 
                   how = 'inner')
Hungary_qual = pd.merge(Hungary, Hungary_qual[['Driver', 'PosQ', 'Q1', 'Q2', 'Q3']], on = 'Driver', 
                   how = 'inner')
Belgium = pd.merge(Belgium, Belgium_qual[['Driver', 'PosQ', 'Q1', 'Q2', 'Q3']], on = 'Driver', 
                   how = 'inner')
Netherlands = pd.merge(Netherlands, Netherlands_qual[['Driver', 'PosQ', 'Q1', 'Q2', 'Q3']], on = 'Driver', 
                   how = 'inner')
Italy = pd.merge(Italy, Italy_qual[['Driver', 'PosQ', 'Q1', 'Q2', 'Q3']], on = 'Driver', 
                   how = 'inner')
Singapore = pd.merge(Singapore, Singapore_qual[['Driver', 'PosQ', 'Q1', 'Q2', 'Q3']], on = 'Driver', 
                   how = 'inner')
Japan = pd.merge(Japan, Japan_qual[['Driver', 'PosQ', 'Q1', 'Q2', 'Q3']], on = 'Driver', 
                   how = 'inner')
Qatar_qual = pd.merge(Qatar, Qatar_qual[['Driver', 'PosQ', 'Q1', 'Q2', 'Q3']], on = 'Driver', 
                   how = 'inner')
US = pd.merge(US, US_qual[['Driver', 'PosQ', 'Q1', 'Q2', 'Q3']], on = 'Driver', 
                   how = 'inner')
Mexico = pd.merge(Mexico, Mexico_qual[['Driver', 'PosQ', 'Q1', 'Q2', 'Q3']], on = 'Driver', 
                   how = 'inner')
Brazil = pd.merge(Brazil, Brazil_qual[['Driver', 'PosQ', 'Q1', 'Q2', 'Q3']], on = 'Driver', 
                   how = 'inner')
Las_vegas = pd.merge(Las_vegas, Las_vegas_qual[['Driver', 'PosQ', 'Q1', 'Q2', 'Q3']], on = 'Driver', 
                   how = 'inner')
Abu_dhabi = pd.merge(Abu_dhabi, Abu_dhabi_qual[['Driver', 'PosQ', 'Q1', 'Q2', 'Q3']], on = 'Driver', 
                   how = 'inner')

# %% [markdown]
# Scraping pit stop data for each race

# %%
Bahrain_pit = scraping_function('https://www.formula1.com/en/results.html/2023/races/1141/bahrain/pit-stop-summary.html')
Saudi_arabia_pit = scraping_function('https://www.formula1.com/en/results.html/2023/races/1142/saudi-arabia/pit-stop-summary.html')
Australia_pit = scraping_function('https://www.formula1.com/en/results.html/2023/races/1143/australia/pit-stop-summary.html')
Azerbaijan_pit = scraping_function('https://www.formula1.com/en/results.html/2023/races/1207/azerbaijan/pit-stop-summary.html')
Miami_pit = scraping_function('https://www.formula1.com/en/results.html/2023/races/1208/miami/pit-stop-summary.html')
Monaco_pit = scraping_function('https://www.formula1.com/en/results.html/2023/races/1210/monaco/pit-stop-summary.html')
Spain_pit = scraping_function('https://www.formula1.com/en/results.html/2023/races/1211/spain/pit-stop-summary.html')
Canada_pit = scraping_function('https://www.formula1.com/en/results.html/2023/races/1212/canada/pit-stop-summary.html')
Austria_pit = scraping_function('https://www.formula1.com/en/results.html/2023/races/1213/austria/pit-stop-summary.html')
Great_britain_pit = scraping_function('https://www.formula1.com/en/results.html/2023/races/1214/great-britain/pit-stop-summary.html')
Hungary_pit = scraping_function('https://www.formula1.com/en/results.html/2023/races/1215/hungary/pit-stop-summary.html')
Belgium_pit = scraping_function('https://www.formula1.com/en/results.html/2023/races/1216/belgium/pit-stop-summary.html')
Netherlands_pit = scraping_function('https://www.formula1.com/en/results.html/2023/races/1217/netherlands/pit-stop-summary.html')
Italy_pit = scraping_function('https://www.formula1.com/en/results.html/2023/races/1218/italy/pit-stop-summary.html')
Singapore_pit = scraping_function('https://www.formula1.com/en/results.html/2023/races/1219/singapore/pit-stop-summary.html')
Japan_pit = scraping_function('https://www.formula1.com/en/results.html/2023/races/1220/japan/pit-stop-summary.html')
Qatar_pit = scraping_function('https://www.formula1.com/en/results.html/2023/races/1221/qatar/pit-stop-summary.html')
US_pit = scraping_function('https://www.formula1.com/en/results.html/2023/races/1222/united-states/pit-stop-summary.html')
Mexico_pit = scraping_function('https://www.formula1.com/en/results.html/2023/races/1223/mexico/pit-stop-summary.html')
Brazil_pit = scraping_function('https://www.formula1.com/en/results.html/2023/races/1224/brazil/pit-stop-summary.html')
Las_vegas_pit = scraping_function('https://www.formula1.com/en/results.html/2023/races/1225/las-vegas/pit-stop-summary.html')
Abu_dhabi_pit = scraping_function('https://www.formula1.com/en/results.html/2023/races/1226/abu-dhabi/pit-stop-summary.html')

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# Below I am adding identifier columns to all the dataframes so that I can join them up together

# %%
races['RaceID'] = races.reset_index().index #adding identifier column to the races dataset
races = races[['RaceID','Date', 'Grand Prix']] #reducing dataframe to  the columns needed for the analysis
races['Date'] = pd.to_datetime(races['Date'], format='%d %b %Y') #converting date column to date format
races
# Out:
# <ipython-input-177-c415762e115c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   races['Date'] = pd.to_datetime(races['Date'], format='%d %b %Y') #converting date column to date format
#     RaceID       Date     Grand Prix
# 0        0 2023-03-05        Bahrain
# 1        1 2023-03-19   Saudi Arabia
# 2        2 2023-04-02      Australia
# 3        3 2023-04-30     Azerbaijan
# 4        4 2023-05-07          Miami
# 5        5 2023-05-28         Monaco
# 6        6 2023-06-04          Spain
# 7        7 2023-06-18         Canada
# 8        8 2023-07-02        Austria
# 9        9 2023-07-09  Great Britain
# 10      10 2023-07-23        Hungary
# 11      11 2023-07-30        Belgium
# 12      12 2023-08-27    Netherlands
# 13      13 2023-09-03          Italy
# 14      14 2023-09-17      Singapore
# 15      15 2023-09-24          Japan
# 16      16 2023-10-08          Qatar
# 17      17 2023-10-22  United States
# 18      18 2023-10-29         Mexico
# 19      19 2023-11-05         Brazil
# 20      20 2023-11-18      Las Vegas
# 21      21 2023-11-26      Abu Dhabi

# %%
drivers['DriverID'] = drivers.reset_index().index #adding identifier column to the driver dataset
drivers = drivers[['DriverID','Driver', 'Nationality', 'Car']] 
drivers
# Out:
#     DriverID                Driver Nationality                           Car
# 0          0    Max Verstappen VER         NED    Red Bull Racing Honda RBPT
# 1          1      Sergio Perez PER         MEX    Red Bull Racing Honda RBPT
# 2          2    Lewis Hamilton HAM         GBR                      Mercedes
# 3          3   Fernando Alonso ALO         ESP  Aston Martin Aramco Mercedes
# 4          4   Charles Leclerc LEC         MON                       Ferrari
# 5          5      Lando Norris NOR         GBR              McLaren Mercedes
# 6          6      Carlos Sainz SAI         ESP                       Ferrari
# 7          7    George Russell RUS         GBR                      Mercedes
# 8          8     Oscar Piastri PIA         AUS              McLaren Mercedes
# 9          9      Lance Stroll STR         CAN  Aston Martin Aramco Mercedes
# 10        10      Pierre Gasly GAS         FRA                Alpine Renault
# 11        11      Esteban Ocon OCO         FRA                Alpine Renault
# 12        12   Alexander Albon ALB         THA             Williams Mercedes
# 13        13      Yuki Tsunoda TSU         JPN         AlphaTauri Honda RBPT
# 14        14   Valtteri Bottas BOT         FIN            Alfa Romeo Ferrari
# 15        15   Nico Hulkenberg HUL         GER                  Haas Ferrari
# 16        16  Daniel Ricciardo RIC         AUS         AlphaTauri Honda RBPT
# 17        17       Zhou Guanyu ZHO         CHN            Alfa Romeo Ferrari
# 18        18   Kevin Magnussen MAG         DEN                  Haas Ferrari
# 19        19       Liam Lawson LAW         NZL         AlphaTauri Honda RBPT
# 20        20    Logan Sargeant SAR         USA             Williams Mercedes
# 21        21     Nyck De Vries DEV         NED         AlphaTauri Honda RBPT

# %%
#Adding identifier columns to individual races datasets
Bahrain['RaceID'] = '0'
Saudi_arabia['RaceID'] = '1'
Australia['RaceID'] = '2'
Azerbaijan['RaceID'] = '3'
Miami['RaceID'] = '4'
Monaco['RaceID'] = '5'
Spain['RaceID'] = '6'
Canada['RaceID'] = '7'
Austria['RaceID'] = '8'
Great_britain['RaceID'] = '9'
Hungary['RaceID'] = '10'
Belgium['RaceID'] = '11'
Netherlands['RaceID'] = '12'
Italy['RaceID'] = '13'
Singapore['RaceID'] = '14'
Japan['RaceID'] = '15'
Qatar['RaceID'] = '16'
US['RaceID'] = '17'
Mexico['RaceID'] = '18'
Brazil['RaceID'] = '19'
Las_vegas['RaceID'] = '20'
Abu_dhabi['RaceID'] = '21'

# %% [markdown]
# Merging dataframes to create the final dataframe

# %%
races_dataframes = [Bahrain, Saudi_arabia, Australia, Azerbaijan, Miami, Monaco, Spain, Canada, Austria, Great_britain, 
                    Hungary, Belgium, Netherlands, Italy, Singapore, Japan, Qatar, US, Mexico, Brazil, Las_vegas, Abu_dhabi]
races_dataframes = pd.concat(races_dataframes, ignore_index=True)
races_dataframes['RaceID'] = races_dataframes['RaceID'].astype(int) #converting the RaceID column from 'object' type to integer to allow me to merge with the Races dataframe
F1_full = pd.merge(races_dataframes, races, on ='RaceID', how='left') #merging Races and Results dataframes
F1_full = F1_full[['RaceID', 'Date', 'Grand Prix', 'Driver', 'Car', 'Pos','PTS', 'Laps', 'PosQ', 'Q1', 'Q2', 'Q3']] #reducing dataframe to the columns we need

# %%
F1_full
# Out:
#      RaceID       Date Grand Prix               Driver  \
# 0         0 2023-03-05    Bahrain   Max Verstappen VER
# 1         0 2023-03-05    Bahrain     Sergio Perez PER
# 2         0 2023-03-05    Bahrain  Fernando Alonso ALO
# 3         0 2023-03-05    Bahrain     Carlos Sainz SAI
# 4         0 2023-03-05    Bahrain   Lewis Hamilton HAM
# ..      ...        ...        ...                  ...
# 434      21 2023-11-26  Abu Dhabi   Logan Sargeant SAR
# 435      21 2023-11-26  Abu Dhabi      Zhou Guanyu ZHO
# 436      21 2023-11-26  Abu Dhabi     Carlos Sainz SAI
# 437      21 2023-11-26  Abu Dhabi  Valtteri Bottas BOT
# 438      21 2023-11-26  Abu Dhabi  Kevin Magnussen MAG
#
#                               Car Pos  PTS  Laps PosQ        Q1        Q2  \
# 0      Red Bull Racing Honda RBPT   1   25    57    1  1:31.295  1:30.503
# 1      Red Bull Racing Honda RBPT   2   18    57    2  1:31.479  1:30.746
# 2    Aston Martin Aramco Mercedes   3   15    57    5  1:31.158  1:30.645
# 3                         Ferrari   4   12    57    4  1:30.993  1:30.515
# 4                        Mercedes   5   10    57    7  1:31.543  1:30.513
# ..                            ...  ..  ...   ...  ...       ...       ...
# 434             Williams Mercedes  16    0    58   NC       DNF       NaN
# 435            Alfa Romeo Ferrari  17    0    58   19  1:25.159       NaN
# 436                       Ferrari  18    0    57   16  1:24.738       NaN
# 437            Alfa Romeo Ferrari  19    0    57   18  1:24.788       NaN
# 438                  Haas Ferrari  20    0    57   17  1:24.764       NaN
#
#            Q3
# 0    1:29.708
# 1    1:29.846
# 2    1:30.336
# 3    1:30.154
# 4    1:30.384
# ..        ...
# 434       NaN
# 435       NaN
# 436       NaN
# 437       NaN
# 438       NaN
#
# [439 rows x 12 columns]

# %%
#Checking for duplicate observations
print(F1_full[F1_full.duplicated()])
# Out:
# Empty DataFrame
# Columns: [RaceID, Date, Grand Prix, Driver, Car, Pos, PTS, Laps, PosQ, Q1, Q2, Q3]
# Index: []

# %%
#Checking for missing values
F1_full.isnull().sum()
# Out:
# RaceID          0
# Date            0
# Grand Prix      0
# Driver          0
# Car             0
# Pos             0
# PTS             0
# Laps            0
# PosQ           80
# Q1             80
# Q2            170
# Q3            259
# dtype: int64

# %% [markdown]
# Note: when checking for missing values no values are identified but we know that there are oibservations under the 'Pos' column with values 'NC' which corresponds to not classified, and 'DQ' corresponding to disqualified. I therefore want to replace these with NaN values so that I can perform calculations on the 'Pos' column

# %%
#replacing NC values in 'Pos' column with 'Nan'
F1_full.replace('NC', np.nan, inplace=True)
F1_full.replace('DQ', np.nan, inplace=True)
F1_full.replace('DNF', np.nan, inplace=True)
F1_full.isnull().sum() #now we can clearly see the missing values in 'Pos' column corresponding to unclassified drivers
# Out:
# RaceID          0
# Date            0
# Grand Prix      0
# Driver          0
# Car             0
# Pos            51
# PTS             0
# Laps            0
# PosQ           87
# Q1             84
# Q2            173
# Q3            263
# dtype: int64

# %%
#checking column datatypes
print(F1_full.dtypes)
# Out:
# RaceID                 int32
# Date          datetime64[ns]
# Grand Prix            object
# Driver                object
# Car                   object
# Pos                   object
# PTS                    int64
# Laps                   int64
# PosQ                  object
# Q1                    object
# Q2                    object
# Q3                    object
# dtype: object

# %%
#conveting Pos and PosQ columns to integer datatype to allow us to perform calculations on this column
F1_full['Pos'] = pd.to_numeric(F1_full['Pos'])
F1_full['PosQ'] = pd.to_numeric(F1_full['PosQ'])
print(F1_full.dtypes)
# Out:
# RaceID                 int32
# Date          datetime64[ns]
# Grand Prix            object
# Driver                object
# Car                   object
# Pos                  float64
# PTS                    int64
# Laps                   int64
# PosQ                 float64
# Q1                    object
# Q2                    object
# Q3                    object
# dtype: object

# %%
F1_full
# Out:
#      RaceID       Date Grand Prix               Driver  \
# 0         0 2023-03-05    Bahrain   Max Verstappen VER
# 1         0 2023-03-05    Bahrain     Sergio Perez PER
# 2         0 2023-03-05    Bahrain  Fernando Alonso ALO
# 3         0 2023-03-05    Bahrain     Carlos Sainz SAI
# 4         0 2023-03-05    Bahrain   Lewis Hamilton HAM
# ..      ...        ...        ...                  ...
# 434      21 2023-11-26  Abu Dhabi   Logan Sargeant SAR
# 435      21 2023-11-26  Abu Dhabi      Zhou Guanyu ZHO
# 436      21 2023-11-26  Abu Dhabi     Carlos Sainz SAI
# 437      21 2023-11-26  Abu Dhabi  Valtteri Bottas BOT
# 438      21 2023-11-26  Abu Dhabi  Kevin Magnussen MAG
#
#                               Car   Pos  PTS  Laps  PosQ        Q1        Q2  \
# 0      Red Bull Racing Honda RBPT   1.0   25    57   1.0  1:31.295  1:30.503
# 1      Red Bull Racing Honda RBPT   2.0   18    57   2.0  1:31.479  1:30.746
# 2    Aston Martin Aramco Mercedes   3.0   15    57   5.0  1:31.158  1:30.645
# 3                         Ferrari   4.0   12    57   4.0  1:30.993  1:30.515
# 4                        Mercedes   5.0   10    57   7.0  1:31.543  1:30.513
# ..                            ...   ...  ...   ...   ...       ...       ...
# 434             Williams Mercedes  16.0    0    58   NaN       NaN       NaN
# 435            Alfa Romeo Ferrari  17.0    0    58  19.0  1:25.159       NaN
# 436                       Ferrari  18.0    0    57  16.0  1:24.738       NaN
# 437            Alfa Romeo Ferrari  19.0    0    57  18.0  1:24.788       NaN
# 438                  Haas Ferrari  20.0    0    57  17.0  1:24.764       NaN
#
#            Q3
# 0    1:29.708
# 1    1:29.846
# 2    1:30.336
# 3    1:30.154
# 4    1:30.384
# ..        ...
# 434       NaN
# 435       NaN
# 436       NaN
# 437       NaN
# 438       NaN
#
# [439 rows x 12 columns]

# %% [markdown]
# ### Cleaning the pit stop dataset

# %%
#Adding identifier column to each pit stop dataframe
Bahrain_pit['RaceID'] = '0'
Saudi_arabia_pit['RaceID'] = '1'
Australia_pit['RaceID'] = '2'
Azerbaijan_pit['RaceID'] = '3'
Miami_pit['RaceID'] = '4'
Monaco_pit['RaceID'] = '5'
Spain_pit['RaceID'] = '6'
Canada_pit['RaceID'] = '7'
Austria_pit['RaceID'] = '8'
Great_britain_pit['RaceID'] = '9'
Hungary_pit['RaceID'] = '10'
Belgium_pit['RaceID'] = '11'
Netherlands_pit['RaceID'] = '12'
Italy_pit['RaceID'] = '13'
Singapore_pit['RaceID'] = '14'
Japan_pit['RaceID'] = '15'
Qatar_pit['RaceID'] = '16'
US_pit['RaceID'] = '17'
Mexico_pit['RaceID'] = '18'
Brazil_pit['RaceID'] = '19'
Las_vegas_pit['RaceID'] = '20'
Abu_dhabi_pit['RaceID'] = '21'

# %%
#Combining all pit stop dataframes into 1 big dataframe
pitstops = [Bahrain_pit, Saudi_arabia_pit,Australia_pit, Azerbaijan_pit, Miami_pit, Monaco_pit, Spain_pit, Canada_pit,
                     Austria_pit, Great_britain_pit, Hungary_pit, Belgium_pit, Netherlands_pit, Italy_pit, Singapore_pit, 
                    Japan_pit, Qatar_pit, US_pit, Mexico_pit, Brazil_pit, Las_vegas_pit, Abu_dhabi_pit]
pitstops_df = pd.concat(pitstops)

# %%
pitstops_df = pitstops_df[['RaceID', 'Driver', 'Car', 'Stops', 'Time', 'Total']]

# %%
#rename columns to make them clearer for my analysis
pitstops_df.rename(columns={'Stops': 'Pitstop_quantity', 'Time': 'Pit_time', 'Total': 'Total_Pit_time'}, inplace=True)

# %%
#checking datatypes
print(pitstops_df.dtypes)
# Out:
# RaceID              object
# Driver              object
# Car                 object
# Pitstop_quantity     int64
# Pit_time            object
# Total_Pit_time      object
# dtype: object

# %%
#modifying datatypes
#Note: when I first tried the code below I find that there are anomalies in the Austrialia_put dataframe where values are in a different format so I have decided to drop these
pitstops_df['Pit_time'] = pd.to_numeric(pitstops_df['Pit_time'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas\_libs\lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "15:25.181"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-195-5f8038aff9dc> in <module>
#       1 #modifying datatypes
#       2 #Note: when I first tried the code below I find that there are anomalies in the Austrialia_put dataframe where values are in a different format so I have decided to drop these
# ----> 3 pitstops_df['Pit_time'] = pd.to_numeric(pitstops_df['Pit_time'])
#
# ~\anaconda3\lib\site-packages\pandas\core\tools\numeric.py in to_numeric(arg, errors, downcast)
#     152         coerce_numeric = errors not in ("ignore", "raise")
#     153         try:
# --> 154             values = lib.maybe_convert_numeric(
#     155                 values, set(), coerce_numeric=coerce_numeric
#     156             )
#
# pandas\_libs\lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "15:25.181" at position 84

# %%
#using regular expressions to match the values in the 'Pit_time' column which have a different pattern and drop these from the dataset as these are not regular pitstops
import re
time_pattern = r'^\d{2}:\d{2}\.\d{3}$'
pitstops_df = pitstops_df[~pitstops_df['Pit_time'].astype(str).str.match(time_pattern)]
time_pattern2 = r'^\d{1}:\d{2}\.\d{3}$'
pitstops_df = pitstops_df[~pitstops_df['Pit_time'].astype(str).str.match(time_pattern2)]
pitstops_df['Pit_time'] = pd.to_numeric(pitstops_df['Pit_time']) #running the code to change the datatype again now that the anomalies have been removed

# %%
#Repeating the procedure above for the total__pit_time column
pitstops_df = pitstops_df[~pitstops_df['Total_Pit_time'].astype(str).str.match(time_pattern)]
pitstops_df = pitstops_df[~pitstops_df['Total_Pit_time'].astype(str).str.match(time_pattern2)]
pitstops_df['Total_Pit_time'] = pd.to_numeric(pitstops_df['Total_Pit_time']) #running the code to change the datatype again now that the anomalies have been removed

# %%
pitstops_df.dtypes #checking datatypes to ensure all necessary columns have been converted
# Out:
# RaceID               object
# Driver               object
# Car                  object
# Pitstop_quantity      int64
# Pit_time            float64
# Total_Pit_time      float64
# dtype: object

# %%
pitstops_df
# Out:
#    RaceID               Driver                           Car  \
# 0       0     Pierre Gasly GAS                Alpine Renault
# 1       0     Lando Norris NOR              McLaren Mercedes
# 2       0     Yuki Tsunoda TSU         AlphaTauri Honda RBPT
# 3       0  Valtteri Bottas BOT            Alfa Romeo Ferrari
# 4       0  Alexander Albon ALB             Williams Mercedes
# ..    ...                  ...                           ...
# 32     21     Sergio Perez PER    Red Bull Racing Honda RBPT
# 33     21     Lance Stroll STR  Aston Martin Aramco Mercedes
# 34     21   Max Verstappen VER    Red Bull Racing Honda RBPT
# 35     21  Alexander Albon ALB             Williams Mercedes
# 36     21     Carlos Sainz SAI                       Ferrari
#
#     Pitstop_quantity  Pit_time  Total_Pit_time
# 0                  1    25.885          25.885
# 1                  1    32.766          32.766
# 2                  1    25.267          25.267
# 3                  1    25.399          25.399
# 4                  1    25.054          25.054
# ..               ...       ...             ...
# 32                 2    21.274          42.720
# 33                 2    21.667          43.533
# 34                 2    21.275          42.937
# 35                 2    21.919          44.089
# 36                 2    21.564          42.793
#
# [634 rows x 6 columns]

# %% [markdown]
# # Creating data insights

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Exploratory Data Analysis

# %%
F1_full.groupby('Driver')['PTS'].sum().sort_values(ascending=False)
# Out:
# Driver
# Max Verstappen VER      530
# Sergio Perez PER        260
# Lewis Hamilton HAM      217
# Fernando Alonso ALO     198
# Charles Leclerc LEC     185
# Lando Norris NOR        184
# Carlos Sainz SAI        178
# George Russell RUS      157
# Oscar Piastri PIA        82
# Lance Stroll STR         68
# Esteban Ocon OCO         56
# Pierre Gasly GAS         54
# Alexander Albon ALB      25
# Yuki Tsunoda TSU         14
# Valtteri Bottas BOT      10
# Zhou Guanyu ZHO           6
# Nico Hulkenberg HUL       6
# Daniel Ricciardo RIC      6
# Kevin Magnussen MAG       3
# Liam Lawson LAW           2
# Logan Sargeant SAR        1
# Nyck De Vries DEV         0
# Name: PTS, dtype: int64

# %%
F1_full.groupby('Car')['PTS'].sum().sort_values(ascending=False)
# Out:
# Car
# Red Bull Racing Honda RBPT      790
# Mercedes                        374
# Ferrari                         363
# Aston Martin Aramco Mercedes    266
# McLaren Mercedes                266
# Alpine Renault                  110
# Williams Mercedes                26
# AlphaTauri Honda RBPT            22
# Alfa Romeo Ferrari               16
# Haas Ferrari                      9
# Name: PTS, dtype: int64

# %%
F1_full.groupby('Driver')['PTS'].describe().round(2)
# Out:
#                       count   mean   std   min    25%   50%    75%   max
# Driver
# Alexander Albon ALB    22.0   1.14  2.01   0.0   0.00   0.0   1.75   6.0
# Carlos Sainz SAI       22.0   8.09  6.08   0.0   4.00   8.0  10.00  25.0
# Charles Leclerc LEC    22.0   8.41  6.70   0.0   0.50   9.0  14.25  18.0
# Daniel Ricciardo RIC    7.0   0.86  2.27   0.0   0.00   0.0   0.00   6.0
# Esteban Ocon OCO       22.0   2.55  4.01   0.0   0.00   1.0   4.00  15.0
# Fernando Alonso ALO    22.0   9.00  6.53   0.0   2.50   9.0  15.00  19.0
# George Russell RUS     22.0   7.14  4.89   0.0   4.25   8.0  10.00  15.0
# Kevin Magnussen MAG    22.0   0.14  0.35   0.0   0.00   0.0   0.00   1.0
# Lance Stroll STR       21.0   3.24  4.11   0.0   0.00   1.0   6.00  12.0
# Lando Norris NOR       22.0   8.36  7.47   0.0   0.50   7.0  17.25  19.0
# Lewis Hamilton HAM     22.0   9.86  5.71   0.0   6.50  10.0  14.50  19.0
# Liam Lawson LAW         5.0   0.40  0.89   0.0   0.00   0.0   0.00   2.0
# Logan Sargeant SAR     22.0   0.05  0.21   0.0   0.00   0.0   0.00   1.0
# Max Verstappen VER     22.0  24.09  3.78  10.0  25.00  25.0  26.00  26.0
# Nico Hulkenberg HUL    22.0   0.27  1.28   0.0   0.00   0.0   0.00   6.0
# Nyck De Vries DEV      10.0   0.00  0.00   0.0   0.00   0.0   0.00   0.0
# Oscar Piastri PIA      22.0   3.73  5.47   0.0   0.00   0.5   5.50  18.0
# Pierre Gasly GAS       22.0   2.45  3.90   0.0   0.00   0.5   3.50  15.0
# Sergio Perez PER       22.0  11.82  7.40   0.0   8.25  12.0  17.25  25.0
# Valtteri Bottas BOT    22.0   0.45  1.18   0.0   0.00   0.0   0.00   4.0
# Yuki Tsunoda TSU       22.0   0.64  1.36   0.0   0.00   0.0   0.75   5.0
# Zhou Guanyu ZHO        22.0   0.27  0.70   0.0   0.00   0.0   0.00   2.0

# %% [markdown]
# ### Team Analysis

# %%
#sorting dataframe by points descending to help us see patterns more clearly 
F1_sorted = F1_full.sort_values(by='PTS', ascending = False).reset_index()
F1_sorted
# Out:
#      index  RaceID       Date     Grand Prix               Driver  \
# 0      419      21 2023-11-26      Abu Dhabi   Max Verstappen VER
# 1      319      16 2023-10-08          Qatar   Max Verstappen VER
# 2      160       8 2023-07-02        Austria   Max Verstappen VER
# 3      299      15 2023-09-24          Japan   Max Verstappen VER
# 4      200      10 2023-07-23        Hungary   Max Verstappen VER
# ..     ...     ...        ...            ...                  ...
# 434    194       9 2023-07-09  Great Britain      Zhou Guanyu ZHO
# 435    193       9 2023-07-09  Great Britain     Lance Stroll STR
# 436    192       9 2023-07-09  Great Britain  Nico Hulkenberg HUL
# 437    191       9 2023-07-09  Great Britain  Valtteri Bottas BOT
# 438    438      21 2023-11-26      Abu Dhabi  Kevin Magnussen MAG
#
#                               Car   Pos  PTS  Laps  PosQ        Q1        Q2  \
# 0      Red Bull Racing Honda RBPT   1.0   26    58   1.0  1:24.160  1:23.740
# 1      Red Bull Racing Honda RBPT   1.0   26    57   NaN       NaN       NaN
# 2      Red Bull Racing Honda RBPT   1.0   26    71   1.0  1:05.116  1:04.951
# 3      Red Bull Racing Honda RBPT   1.0   26    53   1.0  1:29.878  1:29.964
# 4      Red Bull Racing Honda RBPT   1.0   26    70   NaN       NaN       NaN
# ..                            ...   ...  ...   ...   ...       ...       ...
# 434            Alfa Romeo Ferrari  15.0    0    52  17.0  1:30.123       NaN
# 435  Aston Martin Aramco Mercedes  14.0    0    52  12.0  1:29.448  1:28.935
# 436                  Haas Ferrari  13.0    0    52  11.0  1:29.603  1:28.896
# 437            Alfa Romeo Ferrari  12.0    0    52   NaN  1:29.798       NaN
# 438                  Haas Ferrari  20.0    0    57  17.0  1:24.764       NaN
#
#            Q3
# 0    1:23.445
# 1         NaN
# 2    1:04.391
# 3    1:28.877
# 4         NaN
# ..        ...
# 434       NaN
# 435       NaN
# 436       NaN
# 437       NaN
# 438       NaN
#
# [439 rows x 13 columns]

# %%
F1_sorted['Car'].unique() #viewing the teams
# Out:
# array(['Red Bull Racing Honda RBPT', 'Ferrari', 'Mercedes',
#        'Aston Martin Aramco Mercedes', 'McLaren Mercedes',
#        'Alpine Renault', 'AlphaTauri Honda RBPT', 'Williams Mercedes',
#        'Haas Ferrari', 'Alfa Romeo Ferrari'], dtype=object)

# %%
#establishing team colours
team_colours = {'Red Bull Racing Honda RBPT': '#FFCC00','Ferrari': '#DC0000',  'Mercedes' : '#00D2BE', 
                'Aston Martin Aramco Mercedes' : '#006F62' , 'McLaren Mercedes' : '#FF8000','Alpine Renault' : '#FD4BC7',
                'AlphaTauri Honda RBPT' : '#00293F', 'Williams Mercedes' : '#00A3E0',
               'Haas Ferrari' : '#F9F2F2', 'Alfa Romeo Ferrari': '#900000'}
F1_full['Colours'] = F1_sorted['Car'].map(team_colours)
F1_sorted['Colours'] = F1_sorted['Car'].map(team_colours)#mapping colours onto drivers

# %%
F1_team_df = F1_sorted.groupby(['Car','Date']).sum()
F1_full = F1_full.sort_values(by = 'Date') #sorting full F1 dataset by date
F1_full['Cumulative_PTS'] = F1_full.groupby('Car')['PTS'].cumsum() #creating column to hold cumulative values per car team

# %%
plt.figure(figsize = (15,8))
sns.lineplot(data = F1_full, x = 'Date', y = 'Cumulative_PTS', hue = 'Car', marker = 'o') 
plt.xlabel('Date')
plt.ylabel('Points per Team')
plt.legend(title = 'Team', prop = {'size': 12}, fontsize = '10', title_fontsize = '12')
plt.ylim(-10,)
plt.xlim(pd.Timestamp('2023-03'), pd.Timestamp('2023-12'))
plt.show()

# %%
plt.figure(figsize = (10,10))
sns.boxplot(x = 'PTS', y = 'Car', data = F1_sorted, palette = team_colours)
# Out:
# <AxesSubplot:xlabel='PTS', ylabel='Car'>

# %% [markdown]
# The box plots above show the distribution of points for each team on the grid. Although red bull have dominated the 2023 season, this visualisation displays just how dominant the red bull team really is. A key observation here is that the lower quartile for points scored per race is at the same value as the upper quartile for the next best team Ferrari. This chart allows us to really understand how dominant the Red Bull team has been across the 2023 season. Wheras on the other side, AlphaTauri, Williams, Haas, and Alfa Romeo did not have sufficient points to even create a distribution for their season performance, this hilights these 4 as the weakest teams of the season.

# %% [markdown]
# ### Driver Analysis

# %%
plt.figure(figsize = (12,10))
sns.boxplot(data = F1_sorted, x = 'Pos', y = 'Driver', color = 'red')
plt.xlabel('Position')
# Out:
# Text(0.5, 0, 'Position')

# %% [markdown]
# The box plots above show the distribution of position for each driver on the grid. Lando Norris has been identified as the most inconsistent driver due to large spread in finishing positions

# %% [markdown]
# # Analysis of Factors Afffecting Race Results
